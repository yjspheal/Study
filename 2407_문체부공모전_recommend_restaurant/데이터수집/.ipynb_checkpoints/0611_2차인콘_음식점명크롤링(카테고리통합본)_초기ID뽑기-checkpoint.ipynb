# %% [markdown]
# <h1>Table of Contents<span class="tocSkip"></span></h1>
# <div class="toc"><ul class="toc-item"></ul></div>

# %%
# !pip install webdriver_manager
# Out:
# Collecting webdriver_manager
#   Obtaining dependency information for webdriver_manager from https://files.pythonhosted.org/packages/b1/51/b5c11cf739ac4eecde611794a0ec9df420d0239d51e73bc19eb44f02b48b/webdriver_manager-4.0.1-py2.py3-none-any.whl.metadata
#   Using cached webdriver_manager-4.0.1-py2.py3-none-any.whl.metadata (12 kB)
# Requirement already satisfied: requests in ./anaconda3/lib/python3.11/site-packages (from webdriver_manager) (2.31.0)
# Requirement already satisfied: python-dotenv in ./anaconda3/lib/python3.11/site-packages (from webdriver_manager) (1.0.1)
# Requirement already satisfied: packaging in ./anaconda3/lib/python3.11/site-packages (from webdriver_manager) (23.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in ./anaconda3/lib/python3.11/site-packages (from requests->webdriver_manager) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in ./anaconda3/lib/python3.11/site-packages (from requests->webdriver_manager) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in ./anaconda3/lib/python3.11/site-packages (from requests->webdriver_manager) (1.26.16)
# Requirement already satisfied: certifi>=2017.4.17 in ./anaconda3/lib/python3.11/site-packages (from requests->webdriver_manager) (2024.2.2)
# Using cached webdriver_manager-4.0.1-py2.py3-none-any.whl (27 kB)
# Installing collected packages: webdriver_manager
# Successfully installed webdriver_manager-4.0.1

# %%
# 모듈 import
import pandas as pd
from selenium import webdriver
from selenium.webdriver import ActionChains
from selenium.webdriver.support import expected_conditions as EC
from selenium.webdriver.support.ui import WebDriverWait
from webdriver_manager.chrome import ChromeDriverManager
from selenium.webdriver.chrome.service import Service as ChromeService
from selenium.webdriver.common.by import By
from selenium.webdriver.common.keys import Keys
from selenium.common.exceptions import TimeoutException, NoSuchElementException
from bs4 import BeautifulSoup
import time

# %%
target_categories = ['게요리', '곱창,막창,양', '과일,주스전문점', '국밥', '국수', '김밥', '낙지요리', '냉면', 
    '다이어트,샐러드', '닭갈비', '닭발', '도시락,컵밥', '돈가스', '돼지고기구이', '두부요리', 
    '딤섬,중식만두', '떡볶이', '만두', '매운탕,해물탕', '맥주,호프', '바(BAR)', '베이글', '베이커리', 
    '베트남음식', '북카페', '분식', '브런치카페', '샌드위치', '생선회', '샤브샤브', '소고기구이', 
    '스테이크,립', '스파게티,파스타전문', '아시아음식', '양갈비', '양꼬치', '양식', '오뎅,꼬치', 
    '와인', '와플', '요리주점', '우동,소바', '육류,고기요리', '이자카야', '이탈리아음식', '인도음식', 
    '일식당', '일식튀김,꼬치', '장어,먹장어요리', '조개요리', '족발,보쌈', '종합분식', '주꾸미요리', 
    '중식당', '찌개,전골', '초밥,롤', '치킨,닭강정', '카페', '카페,디저트', '칼국수,만두', '케이크전문', 
    '태국음식', '테이크아웃커피', '토스트', '포장마차', '퓨전음식', '프랑스음식', '피자', '한식', 
    '한식뷔페', '한정식-일반', '해물,생선요리', '해장국', '햄버거', '감자탕', '곰탕,설렁탕', '기사식당', 
    '덮밥', '라면', '문래돼지불백', '백반,가정식', '백숙,삼계탕', '복어요리', '빙수', '순대,순댓국', 
    '아이스크림', '오므라이스', '죽', '찜닭', '추어탕', '카레', '패밀리레스토랑', '향토음식', 
    '홍차전문점', '후렌치후라이', '호떡', '쌈밥', '아귀찜,해물찜', '닭볶음탕', '대게요리', '마라탕', 
    '멕시코,남미음식', '브런치', '스페인음식', '정육식당', '전통,민속주점', '일본식라면']

# %%
# 각자 동에 맞는 거로!

restaurant = pd.read_csv('/Users/jeonjoeun/Desktop/서울시마포구일반음식점인허가정보.csv') 
restaurant = restaurant[restaurant['영업상태명'] == '영업/정상']

# NaN 값을 빈 문자열로 대체, 안 하면 에러남
restaurant['지번주소'] = restaurant['지번주소'].fillna('')

# '지번주소' 열이 '서울특별시 마포구 신수동'으로 시작하는 행만 선택
target_dong = '서울특별시 마포구 신수동'
dong = restaurant[restaurant['지번주소'].str.startswith(target_dong)]

# dong에서 도로명주소를 기준으로 검색할 것이기 때문에, 주소 기준 중복인 행을 다 없앰

dong = dong.drop_duplicates(subset='도로명주소', keep=False)
dong.reset_index(drop=True, inplace=True)
dong
# Out:
# /var/folders/vp/1lbpr6tx6x70q4lxyl1flk280000gn/T/ipykernel_2502/3341270938.py:3: DtypeWarning: Columns (32,33,34,35,36,37,38,39,44,45,46,47,48,49,50,63) have mixed types. Specify dtype option on import or set low_memory=False.
#   restaurant = pd.read_csv('/Users/jeonjoeun/Desktop/서울시마포구일반음식점인허가정보.csv')
#      개방자치단체코드                    관리번호       인허가일자  인허가취소일자  영업상태코드  영업상태명  \
# 0     3130000  3130000-101-1983-01146    19831109      NaN       1  영업/정상
# 1     3130000  3130000-101-1984-02309  1984-01-25      NaN       1  영업/정상
# 2     3130000  3130000-101-1987-01152  1987-11-17      NaN       1  영업/정상
# 3     3130000  3130000-101-1990-01155    19900507      NaN       1  영업/정상
# 4     3130000  3130000-101-1990-02876    19901105      NaN       1  영업/정상
# ..        ...                     ...         ...      ...     ...    ...
# 117   3130000  3130000-101-2024-00231  2024-03-14      NaN       1  영업/정상
# 118   3130000  3130000-101-2024-00245  2024-03-18      NaN       1  영업/정상
# 119   3130000  3130000-101-2024-00277  2024-03-27      NaN       1  영업/정상
# 120   3130000  3130000-101-2024-00285  2024-04-01      NaN       1  영업/정상
# 121   3130000  3130000-101-2024-00463  2024-05-29      NaN       1  영업/정상
#
#      상세영업상태코드 상세영업상태명 폐업일자  휴업시작일자  ...  Unnamed: 58  Unnamed: 59 Unnamed: 60  \
# 0           1      영업  NaN     NaN  ...          NaN          NaN         NaN
# 1           1      영업  NaN     NaN  ...          NaN          NaN         NaN
# 2           1      영업  NaN     NaN  ...          NaN          NaN         NaN
# 3           1      영업  NaN     NaN  ...          NaN          NaN         NaN
# 4           1      영업  NaN     NaN  ...          NaN          NaN         NaN
# ..        ...     ...  ...     ...  ...          ...          ...         ...
# 117         1      영업  NaN     NaN  ...          NaN          NaN         NaN
# 118         1      영업  NaN     NaN  ...          NaN          NaN         NaN
# 119         1      영업  NaN     NaN  ...          NaN          NaN         NaN
# 120         1      영업  NaN     NaN  ...          NaN          NaN         NaN
# 121         1      영업  NaN     NaN  ...          NaN          NaN         NaN
#
#      Unnamed: 61 Unnamed: 62 Unnamed: 63 Unnamed: 64 Unnamed: 65 Unnamed: 66  \
# 0            NaN         NaN         NaN         NaN         NaN         NaN
# 1            NaN         NaN         NaN         NaN         NaN         NaN
# 2            NaN         NaN         NaN         NaN         NaN         NaN
# 3            NaN         NaN         NaN         NaN         NaN         NaN
# 4            NaN         NaN         NaN         NaN         NaN         NaN
# ..           ...         ...         ...         ...         ...         ...
# 117          NaN         NaN         NaN         NaN         NaN         NaN
# 118          NaN         NaN         NaN         NaN         NaN         NaN
# 119          NaN         NaN         NaN         NaN         NaN         NaN
# 120          NaN         NaN         NaN         NaN         NaN         NaN
# 121          NaN         NaN         NaN         NaN         NaN         NaN
#
#     Unnamed: 67
# 0           NaN
# 1           NaN
# 2           NaN
# 3           NaN
# 4           NaN
# ..          ...
# 117         NaN
# 118         NaN
# 119         NaN
# 120         NaN
# 121         NaN
#
# [122 rows x 68 columns]

# %%
# webdriver 실행
driver = webdriver.Chrome(service=ChromeService(ChromeDriverManager().install()))

# 검색 결과가 표시되는 iframe으로 전환
def search_iframe():
    driver.switch_to.default_content()  # 차상위 (기본) 프레임으로 전환
    try:
        time.sleep(1.5)  # 페이지 로딩 대기
        driver.switch_to.frame("searchIframe")  # 검색 결과 프레임으로 전환
    except NoSuchElementException:
        print("searchIframe을 찾을 수 없습니다.")
        return False
    return True

# 개별 업체의 세부 정보가 표시되는 iframe으로 전환
def entry_iframe():
    driver.switch_to.default_content()  # 차상위 (기본) 프레임으로 전환
    try:
        time.sleep(1.5)  # 페이지 로딩 대기
        driver.switch_to.frame("entryIframe")  # 세부 정보 프레임으로 전환
    except NoSuchElementException:
        print("entryIframe을 찾을 수 없습니다.")
        return False
    return True

# type1의 화면에 표시된 업체명을 확인하는 함수
def chk_names_type1():
    search_iframe()  # search 프레임으로 전환
    elems = driver.find_elements(By.CLASS_NAME, 'place_bluelink.C6RjW')
    name_list = []
    category_list = []
    elements = []
    
    for e in elems:
        try:
            name = e.find_element(By.CLASS_NAME, 'YwYLL').text
            category = e.find_element(By.CLASS_NAME, 'YzBgS').text
            
            # 업종이 target_categories에 포함되지 않으면 패스
            if category not in target_categories:
                continue
                
            name_list.append(name)
            category_list.append(category)
            elements.append(e)
        except:
            continue
            
    return elements, name_list, category_list

# type2의 화면에 표시된 업체명을 확인하는 함수
def chk_names_type2(processed_names):
    elems = driver.find_elements(By.CLASS_NAME, 'search_box')
    name_list = []
    category_list = []
    elements = []
    
    for e in elems:
        try:
            name = e.find_element(By.CLASS_NAME, 'search_title').text
            category = e.find_element(By.CLASS_NAME, 'category').text
            
            # 이미 처리된 이름은 패스
            if name in processed_names:
                continue
            
            # 업종이 target_categories에 포함되지 않으면 패스
            if category not in target_categories:
                continue
                
            name_list.append(name)
            category_list.append(category)
            elements.append(e)
        except:
            continue
            
    return elements, name_list, category_list

# 세부 페이지에서 URL과 ID를 추출하는 함수 (type1)
def chk_details():
    if not entry_iframe():  # 세부 정보의 iframe으로 전환
        return float('nan'), float('nan')
    soup = BeautifulSoup(driver.page_source, 'html.parser')
    try:
        # 특정 meta 태그를 찾기
        meta_tag = soup.find('meta', {'id': 'og:url'})

        # URL에서 숫자 부분만 추출
        if meta_tag:
            url = meta_tag['content']
            ID = url.split('/')[4]
    except:
        url = float('nan')
        ID = float('nan')

    search_iframe()  # 다시 검색 결과의 iframe으로 전환
    return url, ID

# 세부 페이지에서 URL과 ID를 추출하는 함수 (type2)
def chk_details_type2():
    if not entry_iframe():  # 세부 정보의 iframe으로 전환
        return float('nan'), float('nan')
    soup = BeautifulSoup(driver.page_source, 'html.parser')
    try:
        # 특정 meta 태그를 찾기
        meta_tag = soup.find('meta', {'id': 'og:url'})

        # URL에서 숫자 부분만 추출
        if meta_tag:
            url = meta_tag['content']
            ID = url.split('/')[4]
    except:
        url = float('nan')
        ID = float('nan')

    return url, ID

# 크롤링 메인 함수
def crawling_main(type):
    global naver_res  # 전역변수 naver_res 사용 (크롤링 데이터를 저장하는 데이터프레임)
    global target_dong
    
    processed_names = set()  # 이미 처리된 업체명을 추적하기 위한 집합
    
    if type == "type1":
        elements, name_list, category_list = chk_names_type1()
        details_func = chk_details
        
        id_list = []
        url_list = []

        for e in elements:
            try:
                e.click()  # 업체명 클릭
                time.sleep(1.5)  # 페이지 로딩 대기
                url, ID = details_func()  # 업체의 세부 정보 가져오기
                url_list.append(url)
                id_list.append(ID)

            except:
                url_list.append(float('nan'))
                id_list.append(float('nan'))
                continue
        
        # 새로운 데이터프레임 생성
        naver_temp = pd.DataFrame({
            '지번주소': [current_jibun] * len(name_list),
            '도로명주소': [current_keyword] * len(name_list),
            '업체명': name_list,
            '업종': category_list,
            'URL': url_list,
            'ID': id_list
        })
        
        # 기존 데이터프레임과 결합
        naver_res = pd.concat([naver_res, naver_temp])
        naver_res.reset_index(drop=True, inplace=True)
        naver_res.to_csv(f'./{target_dong.split()[-1]}.csv')  # 결과를 csv 파일로 저장
        
    if type == "type2":
        all_name_list = []
        all_category_list = []
        all_id_list = []
        all_url_list = []
        
        while True:
            elements, name_list, category_list = chk_names_type2(processed_names)
            details_func = chk_details_type2

            if len(elements) == 0:
                break

            for e, name, category in zip(elements, name_list, category_list):
                try:
                    e.click()  # 업체명 클릭
                    time.sleep(1.5)  # 페이지 로딩 대기
                    url, ID = details_func()  # 업체의 세부 정보 가져오기
                    all_url_list.append(url)
                    all_id_list.append(ID)
                    processed_names.add(name)  # 처리된 이름을 추가
                    all_name_list.append(name)
                    all_category_list.append(category)
                    driver.back()  # 뒤로가기 버튼 클릭
                    time.sleep(1.5)  # 뒤로가기 후 페이지 로딩 대기
                except:
                    continue
        
        # 새로운 데이터프레임 생성
        naver_temp = pd.DataFrame({
            '지번주소': [current_jibun] * len(all_name_list),
            '도로명주소': [current_keyword] * len(all_name_list),
            '업체명': all_name_list,
            '업종': all_category_list,
            'URL': all_url_list,
            'ID': all_id_list
        })

        # 기존 데이터프레임과 결합
        naver_res = pd.concat([naver_res, naver_temp])
        naver_res.to_csv(f'./{target_dong.split()[-1]}.csv')  # 결과를 csv 파일로 저장

# 불러올 정보를 담을 빈 데이터프레임 생성
naver_res = pd.DataFrame(columns=['지번주소', '도로명주소', '업체명', '업종', 'URL', 'ID'])

for index, row in dong.iterrows():
    current_jibun = row['지번주소']  # '지번주소'를 저장
    current_keyword = row['도로명주소']  # '도로명주소'를 검색 키워드로 사용
    
    print(f'전체 {len(dong)} 중 {index+1}, 주소:{current_jibun}')
    
    url = f'https://map.naver.com/p/search/{current_keyword}'
    driver.get(url)

    # "sc-1wsjitl dunggE overlap" 클래스가 있는지 확인
    try:
        time.sleep(1.5)  # 페이지 로딩 대기
        overlap_element = driver.find_element(By.CLASS_NAME, 'sc-1wsjitl.dunggE.overlap')
        try:
            more_button = overlap_element.find_element(By.CLASS_NAME, 'link_more')
            more_button.click()
            time.sleep(1.5)  # "더보기" 버튼 클릭 후 페이지 로딩 대기
        except NoSuchElementException:
            pass  # "더보기" 버튼이 없는 경우 그냥 넘어감
        crawling_main("type2")
    except NoSuchElementException:
        try:
            no_result = driver.find_element(By.CLASS_NAME, 'correction_result_text')
            continue
        except:
            try:
                crawling_main("type1")
            except NoSuchElementException:
                continue

    action = ActionChains(driver)
driver.quit()
# Out:
# 전체 122 중 1, 주소:서울특별시 마포구 신수동 86-3번지 1층동
# 전체 122 중 2, 주소:서울특별시 마포구 신수동 39-2
# 전체 122 중 3, 주소:서울특별시 마포구 신수동 10-2
# 전체 122 중 4, 주소:서울특별시 마포구 신수동 49-3번지
# 전체 122 중 5, 주소:서울특별시 마포구 신수동 81-100
# 전체 122 중 6, 주소:서울특별시 마포구 신수동 445-5 신수현대아파트
# 전체 122 중 7, 주소:서울특별시 마포구 신수동 448-23번지
# 전체 122 중 8, 주소:서울특별시 마포구 신수동 184-14번지 1층
# 전체 122 중 9, 주소:서울특별시 마포구 신수동 86-3번지
# 전체 122 중 10, 주소:서울특별시 마포구 신수동 390번지
# 전체 122 중 11, 주소:서울특별시 마포구 신수동 93-31번지
# 전체 122 중 12, 주소:서울특별시 마포구 신수동 184-9번지
# 전체 122 중 13, 주소:서울특별시 마포구 신수동 347
# 전체 122 중 14, 주소:서울특별시 마포구 신수동 88-14번지
# 전체 122 중 15, 주소:서울특별시 마포구 신수동 81-21번지
# 전체 122 중 16, 주소:서울특별시 마포구 신수동 105-2
# 전체 122 중 17, 주소:서울특별시 마포구 신수동 380-9 1층
# 전체 122 중 18, 주소:서울특별시 마포구 신수동 66-2 신촌크리닉존 지하1층103호
# 전체 122 중 19, 주소:서울특별시 마포구 신수동 91-567번지
# 전체 122 중 20, 주소:서울특별시 마포구 신수동 447-1번지 1층
# 전체 122 중 21, 주소:서울특별시 마포구 신수동 339-10번지 1층
# 전체 122 중 22, 주소:서울특별시 마포구 신수동 85-7번지 1층
# 전체 122 중 23, 주소:서울특별시 마포구 신수동 353번지
# 전체 122 중 24, 주소:서울특별시 마포구 신수동 103-4번지
# 전체 122 중 25, 주소:서울특별시 마포구 신수동 81-46번지 2층
# 전체 122 중 26, 주소:서울특별시 마포구 신수동 88-14번지 지1층
# 전체 122 중 27, 주소:서울특별시 마포구 신수동 91-379 1층
# 전체 122 중 28, 주소:서울특별시 마포구 신수동 81-54
# 전체 122 중 29, 주소:서울특별시 마포구 신수동 23-1번지
# 전체 122 중 30, 주소:서울특별시 마포구 신수동 62-16번지 1층
# 전체 122 중 31, 주소:서울특별시 마포구 신수동 88-51
# 전체 122 중 32, 주소:서울특별시 마포구 신수동 451번지
# 전체 122 중 33, 주소:서울특별시 마포구 신수동 350-1 1층
# 전체 122 중 34, 주소:서울특별시 마포구 신수동 68-15번지 B동 105호
# 전체 122 중 35, 주소:서울특별시 마포구 신수동 451
# 전체 122 중 36, 주소:서울특별시 마포구 신수동 22-22
# 전체 122 중 37, 주소:서울특별시 마포구 신수동 81-30
# 전체 122 중 38, 주소:서울특별시 마포구 신수동 85-5
# 전체 122 중 39, 주소:서울특별시 마포구 신수동 85-12
# 전체 122 중 40, 주소:서울특별시 마포구 신수동 81-59
# 전체 122 중 41, 주소:서울특별시 마포구 신수동 85-15
# 전체 122 중 42, 주소:서울특별시 마포구 신수동 89-54
# 전체 122 중 43, 주소:서울특별시 마포구 신수동 406
# 전체 122 중 44, 주소:서울특별시 마포구 신수동 81-30번지
# 전체 122 중 45, 주소:서울특별시 마포구 신수동 436 1층일부
# 전체 122 중 46, 주소:서울특별시 마포구 신수동 52-1번지 1층일부
# 전체 122 중 47, 주소:서울특별시 마포구 신수동 457 마포벽산이-솔렌스힐(아)상가동 107호
# 전체 122 중 48, 주소:서울특별시 마포구 신수동 341-1번지 1층
# 전체 122 중 49, 주소:서울특별시 마포구 신수동 81-23
# 전체 122 중 50, 주소:서울특별시 마포구 신수동 81-136 외6필지 제2서강빌딩 1층일부
# 전체 122 중 51, 주소:서울특별시 마포구 신수동 46-1번지 2층
# 전체 122 중 52, 주소:서울특별시 마포구 신수동 85-19번지
# 전체 122 중 53, 주소:서울특별시 마포구 신수동 288-9번지 1층일부
# 전체 122 중 54, 주소:서울특별시 마포구 신수동 264-3번지 1층일부
# 전체 122 중 55, 주소:서울특별시 마포구 신수동 85-24 1층일부
# 전체 122 중 56, 주소:서울특별시 마포구 신수동 445-6 1층일부
# 전체 122 중 57, 주소:서울특별시 마포구 신수동 88-59번지 1층전체
# 전체 122 중 58, 주소:서울특별시 마포구 신수동 190 성원아파트101동 상가103호
# 전체 122 중 59, 주소:서울특별시 마포구 신수동 89-14번지 1층일부
# 전체 122 중 60, 주소:서울특별시 마포구 신수동 81-64
# 전체 122 중 61, 주소:서울특별시 마포구 신수동 88-32번지
# 전체 122 중 62, 주소:서울특별시 마포구 신수동 404-2번지 1층일부
# 전체 122 중 63, 주소:서울특별시 마포구 신수동 446-1번지
# 전체 122 중 64, 주소:서울특별시 마포구 신수동 85-16
# 전체 122 중 65, 주소:서울특별시 마포구 신수동 50-1번지 1층 일부
# 전체 122 중 66, 주소:서울특별시 마포구 신수동 91-506 1층 상가
# 전체 122 중 67, 주소:서울특별시 마포구 신수동 66-10번지 101호
# 전체 122 중 68, 주소:서울특별시 마포구 신수동 89-10번지
# 전체 122 중 69, 주소:서울특별시 마포구 신수동 85-13
# 전체 122 중 70, 주소:서울특별시 마포구 신수동 81-63번지
# 전체 122 중 71, 주소:서울특별시 마포구 신수동 88-49번지
# 전체 122 중 72, 주소:서울특별시 마포구 신수동 27-2번지
# 전체 122 중 73, 주소:서울특별시 마포구 신수동 392-2번지
# 전체 122 중 74, 주소:서울특별시 마포구 신수동 85-11번지
# 전체 122 중 75, 주소:서울특별시 마포구 신수동 23-1 1층
# 전체 122 중 76, 주소:서울특별시 마포구 신수동 431-3번지 토형빌딩
# 전체 122 중 77, 주소:서울특별시 마포구 신수동 422
# 전체 122 중 78, 주소:서울특별시 마포구 신수동 179-2
# 전체 122 중 79, 주소:서울특별시 마포구 신수동 450번지 신촌삼익아파트
# 전체 122 중 80, 주소:서울특별시 마포구 신수동 91-385
# 전체 122 중 81, 주소:서울특별시 마포구 신수동 9-10번지
# 전체 122 중 82, 주소:서울특별시 마포구 신수동 440-1번지 성산빌딩
# 전체 122 중 83, 주소:서울특별시 마포구 신수동 381-11
# 전체 122 중 84, 주소:서울특별시 마포구 신수동 93-190
# 전체 122 중 85, 주소:서울특별시 마포구 신수동 81-16
# 전체 122 중 86, 주소:서울특별시 마포구 신수동 42-5
# 전체 122 중 87, 주소:서울특별시 마포구 신수동 345-6
# 전체 122 중 88, 주소:서울특별시 마포구 신수동 448-8
# 전체 122 중 89, 주소:서울특별시 마포구 신수동 421-2
# 전체 122 중 90, 주소:서울특별시 마포구 신수동 89-6
# 전체 122 중 91, 주소:서울특별시 마포구 신수동 91-375 윤
# 전체 122 중 92, 주소:서울특별시 마포구 신수동 448-2
# 전체 122 중 93, 주소:서울특별시 마포구 신수동 81-59
# 전체 122 중 94, 주소:서울특별시 마포구 신수동 178-3
# 전체 122 중 95, 주소:서울특별시 마포구 신수동 85-28
# 전체 122 중 96, 주소:서울특별시 마포구 신수동 85-15
# 전체 122 중 97, 주소:서울특별시 마포구 신수동 41-2
# 전체 122 중 98, 주소:서울특별시 마포구 신수동 1-24 서강더하우스
# 전체 122 중 99, 주소:서울특별시 마포구 신수동 88-131
# 전체 122 중 100, 주소:서울특별시 마포구 신수동 63-14 거구장
# 전체 122 중 101, 주소:서울특별시 마포구 신수동 89-93
# 전체 122 중 102, 주소:서울특별시 마포구 신수동 380-3
# 전체 122 중 103, 주소:서울특별시 마포구 신수동 62-18 신수동 근생및 단독주택
# 전체 122 중 104, 주소:서울특별시 마포구 신수동 351
# 전체 122 중 105, 주소:서울특별시 마포구 신수동 81-22
# 전체 122 중 106, 주소:서울특별시 마포구 신수동 290-1
# 전체 122 중 107, 주소:서울특별시 마포구 신수동 88-13
# 전체 122 중 108, 주소:서울특별시 마포구 신수동 93-211
# 전체 122 중 109, 주소:서울특별시 마포구 신수동 93-21
# 전체 122 중 110, 주소:서울특별시 마포구 신수동 399
# 전체 122 중 111, 주소:서울특별시 마포구 신수동 85-30 노블하우스
# 전체 122 중 112, 주소:서울특별시 마포구 신수동 85-24
# 전체 122 중 113, 주소:서울특별시 마포구 신수동 93-212
# 전체 122 중 114, 주소:서울특별시 마포구 신수동 89-54
# 전체 122 중 115, 주소:서울특별시 마포구 신수동 91-567 원인터빌딩
# 전체 122 중 116, 주소:서울특별시 마포구 신수동 81-63
# 전체 122 중 117, 주소:서울특별시 마포구 신수동 300 예원피아노
# 전체 122 중 118, 주소:서울특별시 마포구 신수동 91-389 춘추가원
# 전체 122 중 119, 주소:서울특별시 마포구 신수동 36-3
# 전체 122 중 120, 주소:서울특별시 마포구 신수동 41-7
# 전체 122 중 121, 주소:서울특별시 마포구 신수동 101-32
# 전체 122 중 122, 주소:서울특별시 마포구 신수동 91-15

# %%
naver_res
# Out:
#                          지번주소                    도로명주소         업체명       업종  \
# 0    서울특별시 마포구 신수동 86-3번지 1층동         서울특별시 마포구 백범로 48   서강순대국뼈해장국   순대,순댓국
# 1    서울특별시 마포구 신수동 86-3번지 1층동         서울특별시 마포구 백범로 48       용궁설렁탕   곰탕,설렁탕
# 2          서울특별시 마포구 신수동 39-2  서울특별시 마포구 독막로 240 (신수동)          국빈      중식당
# 3          서울특별시 마포구 신수동 10-2   서울특별시 마포구 백범로 68 (신수동)   김밥천국 서강대점       분식
# 4          서울특별시 마포구 신수동 10-2   서울특별시 마포구 백범로 68 (신수동)  세아마라탕 서강대점      중식당
# ..                        ...                      ...         ...      ...
# 0   서울특별시 마포구 신수동 91-389 춘추가원       서울특별시 마포구 광성로 31-1        멘야요시     종합분식
# 0          서울특별시 마포구 신수동 36-3      서울특별시 마포구 백범로10길 30     리정원 대흥점  육류,고기요리
# 0          서울특별시 마포구 신수동 41-7      서울특별시 마포구 독막로34길 10       오프스크린   카페,디저트
# 0         서울특별시 마포구 신수동 91-15         서울특별시 마포구 광성로 20        까치커피   카페,디저트
# 1         서울특별시 마포구 신수동 91-15         서울특별시 마포구 광성로 20       카페드루앙   카페,디저트
#
#                                                   URL          ID
# 0   https://pcmap.place.naver.com/restaurant/19718...  1971840025
# 1   https://pcmap.place.naver.com/restaurant/18776...    18776764
# 2   https://pcmap.place.naver.com/restaurant/18333...    18333168
# 3   https://pcmap.place.naver.com/restaurant/19927...  1992768383
# 4   https://pcmap.place.naver.com/restaurant/10844...  1084492489
# ..                                                ...         ...
# 0   https://pcmap.place.naver.com/restaurant/11345...  1134539849
# 0   https://pcmap.place.naver.com/restaurant/16493...  1649349828
# 0   https://pcmap.place.naver.com/restaurant/18683...  1868335886
# 0   https://pcmap.place.naver.com/restaurant/11258...  1125826561
# 1   https://pcmap.place.naver.com/restaurant/18647...  1864790682
#
# [189 rows x 6 columns]

# %%
# 중복행 제거
naver_res_drop = naver_res.drop_duplicates(subset='ID', keep='first')

# %%
naver_res_drop
# Out:
#                          지번주소                    도로명주소         업체명       업종  \
# 0    서울특별시 마포구 신수동 86-3번지 1층동         서울특별시 마포구 백범로 48   서강순대국뼈해장국   순대,순댓국
# 1    서울특별시 마포구 신수동 86-3번지 1층동         서울특별시 마포구 백범로 48       용궁설렁탕   곰탕,설렁탕
# 2          서울특별시 마포구 신수동 39-2  서울특별시 마포구 독막로 240 (신수동)          국빈      중식당
# 3          서울특별시 마포구 신수동 10-2   서울특별시 마포구 백범로 68 (신수동)   김밥천국 서강대점       분식
# 4          서울특별시 마포구 신수동 10-2   서울특별시 마포구 백범로 68 (신수동)  세아마라탕 서강대점      중식당
# ..                        ...                      ...         ...      ...
# 0   서울특별시 마포구 신수동 91-389 춘추가원       서울특별시 마포구 광성로 31-1        멘야요시     종합분식
# 0          서울특별시 마포구 신수동 36-3      서울특별시 마포구 백범로10길 30     리정원 대흥점  육류,고기요리
# 0          서울특별시 마포구 신수동 41-7      서울특별시 마포구 독막로34길 10       오프스크린   카페,디저트
# 0         서울특별시 마포구 신수동 91-15         서울특별시 마포구 광성로 20        까치커피   카페,디저트
# 1         서울특별시 마포구 신수동 91-15         서울특별시 마포구 광성로 20       카페드루앙   카페,디저트
#
#                                                   URL          ID
# 0   https://pcmap.place.naver.com/restaurant/19718...  1971840025
# 1   https://pcmap.place.naver.com/restaurant/18776...    18776764
# 2   https://pcmap.place.naver.com/restaurant/18333...    18333168
# 3   https://pcmap.place.naver.com/restaurant/19927...  1992768383
# 4   https://pcmap.place.naver.com/restaurant/10844...  1084492489
# ..                                                ...         ...
# 0   https://pcmap.place.naver.com/restaurant/11345...  1134539849
# 0   https://pcmap.place.naver.com/restaurant/16493...  1649349828
# 0   https://pcmap.place.naver.com/restaurant/18683...  1868335886
# 0   https://pcmap.place.naver.com/restaurant/11258...  1125826561
# 1   https://pcmap.place.naver.com/restaurant/18647...  1864790682
#
# [157 rows x 6 columns]

# %%
# CSV 파일로 저장
naver_res_drop.to_csv('0611_naver_res_drop.csv', index=False)
