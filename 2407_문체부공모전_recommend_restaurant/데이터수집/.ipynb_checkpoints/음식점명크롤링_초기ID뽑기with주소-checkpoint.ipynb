# %% [markdown]
# <h1>Table of Contents<span class="tocSkip"></span></h1>
# <div class="toc"><ul class="toc-item"></ul></div>

# %%
# 모듈 import
import pandas as pd
from selenium import webdriver
from selenium.webdriver import ActionChains
from selenium.webdriver.support import expected_conditions as EC
from selenium.webdriver.support.ui import WebDriverWait
from webdriver_manager.chrome import ChromeDriverManager
from selenium.webdriver.chrome.service import Service as ChromeService
from selenium.webdriver.common.by import By
from selenium.webdriver.common.keys import Keys
from selenium.common.exceptions import TimeoutException, NoSuchElementException


from bs4 import BeautifulSoup
import time

# %%
target_categories = ['게요리',
 '곱창,막창,양',
 '과일,주스전문점',
 '국밥',
 '김밥',
 '낙지요리',
 '다이어트,샐러드',
 '닭갈비',
 '닭발',
 '닭볶음탕',
 '닭요리',
 '대게요리',
 '덮밥',
 '도시락,컵밥',
 '돈가스',
 '돼지고기구이',
 '떡볶이', '라면'
 '마라탕',
 '만두',                
 '맥주,호프',
 '멕시코,남미음식',
 '바(BAR)',
 '백반,가정식',
 '베이커리',
 '베트남음식',
 '분식',
 '빙수',
 '복어요리',                     
 '생선회',
 '샤브샤브',
 '소고기구이',
 '순대,순댓국',
 '술집',
 '스테이크,립',
 '스파게티,파스타전문',
 '아시아음식',
 '양꼬치',
 '양식',
 '오므라이스',
 '요리주점',
 '육류,고기요리',
 '이자카야',
 '이탈리아음식',
 '인도음식',
 '일본식라면',
 '일식당',
 '일식튀김,꼬치',
 '족발,보쌈',
 '주꾸미요리',
 '중식당',
 '찜닭',
 '초밥,롤',
 '치킨,닭강정',
 '카레',
 '카페',
 '카페,디저트',
 '칼국수,만두',
 '태국음식',
 '프랑스음식',
 '피자',
 '한식',
 '해물,생선요리',
 '햄버거',
 '향토음식',
 '홍차전문점']

# %%
# 각자 동에 맞는 거로!

restaurant = pd.read_csv('./서울시서대문구일반음식점인허가정보.csv', encoding = 'cp949') 
restaurant = restaurant[restaurant['영업상태명'] == '영업/정상']

# NaN 값을 빈 문자열로 대체, 안 하면 에러남
restaurant['지번주소'] = restaurant['지번주소'].fillna('')

# '지번주소' 열이 '서울특별시 서대문구 창천동'으로 시작하는 행만 선택
target_dong = '서울특별시 서대문구 창천동'
dong = restaurant[restaurant['지번주소'].str.startswith(target_dong)]

# dong에서 도로명주소를 기준으로 검색할 것이기 때문에, 주소 기준 중복인 행을 다 없앰

dong = dong.drop_duplicates(subset='도로명주소', keep=False)
dong.reset_index(drop=True, inplace=True)
dong
# Out:
# C:\Users\uje10\AppData\Local\Temp\ipykernel_6188\2278605232.py:3: DtypeWarning: Columns (13,28,29,30,41,42) have mixed types. Specify dtype option on import or set low_memory=False.
#   restaurant = pd.read_csv('./서울시서대문구일반음식점인허가정보.csv', encoding = 'cp949')
#      개방자치단체코드                    관리번호       인허가일자  인허가취소일자  영업상태코드  영업상태명  \
# 0     3120000  3120000-101-1971-05561    19710811      NaN       1  영업/정상
# 1     3120000  3120000-101-1977-00201    19770808      NaN       1  영업/정상
# 2     3120000  3120000-101-1977-00342    19770803      NaN       1  영업/정상
# 3     3120000  3120000-101-1977-01871    19770609      NaN       1  영업/정상
# 4     3120000  3120000-101-1978-09255    19781220      NaN       1  영업/정상
# ..        ...                     ...         ...      ...     ...    ...
# 639   3120000  3120000-101-2024-00134  2024-04-26      NaN       1  영업/정상
# 640   3120000  3120000-101-2024-00141  2024-05-01      NaN       1  영업/정상
# 641   3120000  3120000-101-2024-00145  2024-05-02      NaN       1  영업/정상
# 642   3120000  3120000-101-2024-00156  2024-05-13      NaN       1  영업/정상
# 643   3120000  3120000-101-2024-00163  2024-05-17      NaN       1  영업/정상
#
#      상세영업상태코드 상세영업상태명 폐업일자  휴업시작일자  ...  공장판매직종업원수  공장생산직종업원수 건물소유구분명 보증액 월세액  \
# 0           1      영업  NaN     NaN  ...        NaN        NaN     NaN NaN NaN
# 1           1      영업  NaN     NaN  ...        NaN        NaN     NaN NaN NaN
# 2           1      영업  NaN     NaN  ...        NaN        NaN     NaN NaN NaN
# 3           1      영업  NaN     NaN  ...        NaN        NaN     NaN NaN NaN
# 4           1      영업  NaN     NaN  ...        NaN        NaN     NaN NaN NaN
# ..        ...     ...  ...     ...  ...        ...        ...     ...  ..  ..
# 639         1      영업  NaN     NaN  ...        NaN        NaN     NaN NaN NaN
# 640         1      영업  NaN     NaN  ...        NaN        NaN     NaN NaN NaN
# 641         1      영업  NaN     NaN  ...        NaN        NaN     NaN NaN NaN
# 642         1      영업  NaN     NaN  ...        NaN        NaN     NaN NaN NaN
# 643         1      영업  NaN     NaN  ...        NaN        NaN     NaN NaN NaN
#
#     다중이용업소여부   시설총규모  전통업소지정번호 전통업소주된음식 홈페이지
# 0          N   57.87       NaN      NaN  NaN
# 1          N   19.80       NaN      NaN  NaN
# 2          N   67.00       NaN      NaN  NaN
# 3        NaN     NaN       NaN      NaN  NaN
# 4          Y  357.17       NaN      NaN  NaN
# ..       ...     ...       ...      ...  ...
# 639      NaN     NaN       NaN      NaN  NaN
# 640      NaN     NaN       NaN      NaN  NaN
# 641      NaN     NaN       NaN      NaN  NaN
# 642      NaN     NaN       NaN      NaN  NaN
# 643      NaN     NaN       NaN      NaN  NaN
#
# [644 rows x 44 columns]

# %%
# webdriver 실행
driver = webdriver.Chrome(service=ChromeService(ChromeDriverManager().install()))

# 검색 결과가 표시되는 iframe으로 전환
def search_iframe():
    driver.switch_to.default_content()  # 차상위 (기본) 프레임으로 전환
    try:
        time.sleep(1.5)  # 페이지 로딩 대기
        driver.switch_to.frame("searchIframe")  # 검색 결과 프레임으로 전환
    except NoSuchElementException:
        print("searchIframe을 찾을 수 없습니다.")
        return False
    return True

# 개별 업체의 세부 정보가 표시되는 iframe으로 전환
def entry_iframe():
    driver.switch_to.default_content()  # 차상위 (기본) 프레임으로 전환
    try:
        time.sleep(1.5)  # 페이지 로딩 대기
        driver.switch_to.frame("entryIframe")  # 세부 정보 프레임으로 전환
    except NoSuchElementException:
        print("entryIframe을 찾을 수 없습니다.")
        return False
    return True

# type1의 화면에 표시된 업체명을 확인하는 함수
def chk_names_type1():
    search_iframe()  # search 프레임으로 전환
    elems = driver.find_elements(By.CLASS_NAME, 'place_bluelink.C6RjW')
    name_list = []
    category_list = []
    elements = []
    
    for e in elems:
        try:
            name = e.find_element(By.CLASS_NAME, 'YwYLL').text
            category = e.find_element(By.CLASS_NAME, 'YzBgS').text
            
            # 업종이 target_categories에 포함되지 않으면 패스
            if category not in target_categories:
                continue
                
            name_list.append(name)
            category_list.append(category)
            elements.append(e)
        except:
            continue
            
    return elements, name_list, category_list

# type2의 화면에 표시된 업체명을 확인하는 함수
def chk_names_type2(processed_names):
    elems = driver.find_elements(By.CLASS_NAME, 'search_box')
    name_list = []
    category_list = []
    elements = []
    
    for e in elems:
        try:
            name = e.find_element(By.CLASS_NAME, 'search_title').text
            category = e.find_element(By.CLASS_NAME, 'category').text
            
            # 이미 처리된 이름은 패스
            if name in processed_names:
                continue
            
            # 업종이 target_categories에 포함되지 않으면 패스
            if category not in target_categories:
                continue
                
            name_list.append(name)
            category_list.append(category)
            elements.append(e)
        except:
            continue
            
    return elements, name_list, category_list

# 세부 페이지에서 URL과 ID를 추출하는 함수 (type1)
def chk_details():
    if not entry_iframe():  # 세부 정보의 iframe으로 전환
        return float('nan'), float('nan')
    soup = BeautifulSoup(driver.page_source, 'html.parser')
    try:
        # 특정 meta 태그를 찾기
        meta_tag = soup.find('meta', {'id': 'og:url'})

        # URL에서 숫자 부분만 추출
        if meta_tag:
            url = meta_tag['content']
            ID = url.split('/')[4]
    except:
        url = float('nan')
        ID = float('nan')

    search_iframe()  # 다시 검색 결과의 iframe으로 전환
    return url, ID

# 세부 페이지에서 URL과 ID를 추출하는 함수 (type2)
def chk_details_type2():
    if not entry_iframe():  # 세부 정보의 iframe으로 전환
        return float('nan'), float('nan')
    soup = BeautifulSoup(driver.page_source, 'html.parser')
    try:
        # 특정 meta 태그를 찾기
        meta_tag = soup.find('meta', {'id': 'og:url'})

        # URL에서 숫자 부분만 추출
        if meta_tag:
            url = meta_tag['content']
            ID = url.split('/')[4]
    except:
        url = float('nan')
        ID = float('nan')

    return url, ID

# 크롤링 메인 함수
def crawling_main(type):
    global naver_res  # 전역변수 naver_res 사용 (크롤링 데이터를 저장하는 데이터프레임)
    global target_dong
    
    processed_names = set()  # 이미 처리된 업체명을 추적하기 위한 집합
    
    if type == "type1":
        elements, name_list, category_list = chk_names_type1()
        details_func = chk_details
        
        id_list = []
        url_list = []

        for e in elements:
            try:
                e.click()  # 업체명 클릭
                time.sleep(1.5)  # 페이지 로딩 대기
                url, ID = details_func()  # 업체의 세부 정보 가져오기
                url_list.append(url)
                id_list.append(ID)

            except:
                url_list.append(float('nan'))
                id_list.append(float('nan'))
                continue
        
        # 새로운 데이터프레임 생성
        naver_temp = pd.DataFrame({
            '지번주소': [current_jibun] * len(name_list),
            '도로명주소': [current_keyword] * len(name_list),
            '업체명': name_list,
            '업종': category_list,
            'URL': url_list,
            'ID': id_list
        })
        
        # 기존 데이터프레임과 결합
        naver_res = pd.concat([naver_res, naver_temp])
        naver_res.reset_index(drop=True, inplace=True)
        naver_res.to_csv(f'./{target_dong.split()[-1]}.csv')  # 결과를 csv 파일로 저장
        
    if type == "type2":
        all_name_list = []
        all_category_list = []
        all_id_list = []
        all_url_list = []
        
        while True:
            elements, name_list, category_list = chk_names_type2(processed_names)
            details_func = chk_details_type2

            if len(elements) == 0:
                break

            for e, name, category in zip(elements, name_list, category_list):
                try:
                    e.click()  # 업체명 클릭
                    time.sleep(1.5)  # 페이지 로딩 대기
                    url, ID = details_func()  # 업체의 세부 정보 가져오기
                    all_url_list.append(url)
                    all_id_list.append(ID)
                    processed_names.add(name)  # 처리된 이름을 추가
                    all_name_list.append(name)
                    all_category_list.append(category)
                    driver.back()  # 뒤로가기 버튼 클릭
                    time.sleep(1.5)  # 뒤로가기 후 페이지 로딩 대기
                except:
                    continue
        
        # 새로운 데이터프레임 생성
        naver_temp = pd.DataFrame({
            '지번주소': [current_jibun] * len(all_name_list),
            '도로명주소': [current_keyword] * len(all_name_list),
            '업체명': all_name_list,
            '업종': all_category_list,
            'URL': all_url_list,
            'ID': all_id_list
        })

        # 기존 데이터프레임과 결합
        naver_res = pd.concat([naver_res, naver_temp])
        naver_res.to_csv(f'./{target_dong.split()[-1]}.csv')  # 결과를 csv 파일로 저장

# 불러올 정보를 담을 빈 데이터프레임 생성
naver_res = pd.DataFrame(columns=['지번주소', '도로명주소', '업체명', '업종', 'URL', 'ID'])

for index, row in dong.iterrows():
    current_jibun = row['지번주소']  # '지번주소'를 저장
    current_keyword = row['도로명주소']  # '도로명주소'를 검색 키워드로 사용
    
    print(f'전체 {len(dong)} 중 {index+1}, 주소:{current_jibun}')
    
    url = f'https://map.naver.com/p/search/{current_keyword}'
    driver.get(url)

    # "sc-1wsjitl dunggE overlap" 클래스가 있는지 확인
    try:
        time.sleep(1.5)  # 페이지 로딩 대기
        overlap_element = driver.find_element(By.CLASS_NAME, 'sc-1wsjitl.dunggE.overlap')
        try:
            more_button = overlap_element.find_element(By.CLASS_NAME, 'link_more')
            more_button.click()
            time.sleep(1.5)  # "더보기" 버튼 클릭 후 페이지 로딩 대기
        except NoSuchElementException:
            pass  # "더보기" 버튼이 없는 경우 그냥 넘어감
        crawling_main("type2")
    except NoSuchElementException:
        try:
            no_result = driver.find_element(By.CLASS_NAME, 'correction_result_text')
            continue
        except:
            try:
                crawling_main("type1")
            except NoSuchElementException:
                continue

    action = ActionChains(driver)
correction_result_text
driver.quit()
# Out:
# 전체 644 중 26, 주소:서울특별시 서대문구 창천동 33-36
# 전체 644 중 27, 주소:서울특별시 서대문구 창천동 52-5 ,6,7
# 전체 644 중 28, 주소:서울특별시 서대문구 창천동 33-55
# 전체 644 중 29, 주소:서울특별시 서대문구 창천동 72-10 (지상1,2층)
# 전체 644 중 30, 주소:서울특별시 서대문구 창천동 13-26
# 전체 644 중 31, 주소:서울특별시 서대문구 창천동 33-14 지상2층
# 전체 644 중 32, 주소:서울특별시 서대문구 창천동 13-13번지
# 전체 644 중 33, 주소:서울특별시 서대문구 창천동 62-5번지 1층
# 전체 644 중 34, 주소:서울특별시 서대문구 창천동 52-12번지 지하1층
# 전체 644 중 35, 주소:서울특별시 서대문구 창천동 52-152 지하1층
# 전체 644 중 36, 주소:서울특별시 서대문구 창천동 52-155 1층
# 전체 644 중 37, 주소:서울특별시 서대문구 창천동 52-11번지
# 전체 644 중 38, 주소:서울특별시 서대문구 창천동 46-2 ,3
# 전체 644 중 39, 주소:서울특별시 서대문구 창천동 52-32 지하1층
# 전체 644 중 40, 주소:서울특별시 서대문구 창천동 52-65번지 2층
# 전체 644 중 41, 주소:서울특별시 서대문구 창천동 52-77번지
# 전체 644 중 42, 주소:서울특별시 서대문구 창천동 52-44 1층
# 전체 644 중 43, 주소:서울특별시 서대문구 창천동 62-59
# 전체 644 중 44, 주소:서울특별시 서대문구 창천동 52-8번지
# 전체 644 중 45, 주소:서울특별시 서대문구 창천동 33-43
# 전체 644 중 46, 주소:서울특별시 서대문구 창천동 5-94 (지하1층)
# 전체 644 중 47, 주소:서울특별시 서대문구 창천동 52-79 2층 전체
# 전체 644 중 48, 주소:서울특별시 서대문구 창천동 5-63번지
# 전체 644 중 49, 주소:서울특별시 서대문구 창천동 52-75번지
# 전체 644 중 50, 주소:서울특별시 서대문구 창천동 62-66 1층 전체

# %%
naver_res
# Out:
#                           지번주소                             도로명주소  \
# 0        서울특별시 서대문구 창천동 33-36            서울특별시 서대문구 연세로 25 (창천동)
# 1        서울특별시 서대문구 창천동 33-36            서울특별시 서대문구 연세로 25 (창천동)
# 2        서울특별시 서대문구 창천동 33-36            서울특별시 서대문구 연세로 25 (창천동)
# 0     서울특별시 서대문구 창천동 52-5 ,6,7     서울특별시 서대문구 연세로11길 8, 2층 (창천동)
# 0         서울특별시 서대문구 창천동 33-55         서울특별시 서대문구 연세로7안길 4 (창천동)
# 1         서울특별시 서대문구 창천동 33-55         서울특별시 서대문구 연세로7안길 4 (창천동)
# 2         서울특별시 서대문구 창천동 33-55         서울특별시 서대문구 연세로7안길 4 (창천동)
# 3         서울특별시 서대문구 창천동 33-55         서울특별시 서대문구 연세로7안길 4 (창천동)
# 4         서울특별시 서대문구 창천동 33-55         서울특별시 서대문구 연세로7안길 4 (창천동)
# 5         서울특별시 서대문구 창천동 33-55         서울특별시 서대문구 연세로7안길 4 (창천동)
# 6         서울특별시 서대문구 창천동 33-55         서울특별시 서대문구 연세로7안길 4 (창천동)
# 7         서울특별시 서대문구 창천동 33-55         서울특별시 서대문구 연세로7안길 4 (창천동)
# 8         서울특별시 서대문구 창천동 33-55         서울특별시 서대문구 연세로7안길 4 (창천동)
# 0    서울특별시 서대문구 창천동 33-14 지상2층      서울특별시 서대문구 연세로9길 8 (창천동, 2층)
# 0      서울특별시 서대문구 창천동 13-13번지      서울특별시 서대문구 연세로4길 33, 2층 (창천동)
# 1      서울특별시 서대문구 창천동 13-13번지      서울특별시 서대문구 연세로4길 33, 2층 (창천동)
# 0    서울특별시 서대문구 창천동 62-5번지 1층      서울특별시 서대문구 연세로5다길 6, 1층 (창천동)
# 0   서울특별시 서대문구 창천동 52-152 지하1층  서울특별시 서대문구 연세로11길 29, 지하1층 (창천동)
# 0     서울특별시 서대문구 창천동 52-155 1층    서울특별시 서대문구 연세로11길 20 (창천동, 1층)
# 1     서울특별시 서대문구 창천동 52-155 1층    서울특별시 서대문구 연세로11길 20 (창천동, 1층)
# 0      서울특별시 서대문구 창천동 52-11번지         서울특별시 서대문구 연세로11길 24 (창천동)
# 1      서울특별시 서대문구 창천동 52-11번지         서울특별시 서대문구 연세로11길 24 (창천동)
# 2      서울특별시 서대문구 창천동 52-11번지         서울특별시 서대문구 연세로11길 24 (창천동)
# 0      서울특별시 서대문구 창천동 46-2 ,3      서울특별시 서대문구 연세로12길 22 (창천동,,3)
# 1      서울특별시 서대문구 창천동 46-2 ,3      서울특별시 서대문구 연세로12길 22 (창천동,,3)
# 0   서울특별시 서대문구 창천동 52-32 지하1층    서울특별시 서대문구 연세로9길 22, 지하1층 (창천동)
# 1   서울특별시 서대문구 창천동 52-32 지하1층    서울특별시 서대문구 연세로9길 22, 지하1층 (창천동)
# 2   서울특별시 서대문구 창천동 52-32 지하1층    서울특별시 서대문구 연세로9길 22, 지하1층 (창천동)
# 3   서울특별시 서대문구 창천동 52-32 지하1층    서울특별시 서대문구 연세로9길 22, 지하1층 (창천동)
# 4   서울특별시 서대문구 창천동 52-32 지하1층    서울특별시 서대문구 연세로9길 22, 지하1층 (창천동)
# 0   서울특별시 서대문구 창천동 52-65번지 2층     서울특별시 서대문구 연세로7안길 21, 2층 (창천동)
# 1   서울특별시 서대문구 창천동 52-65번지 2층     서울특별시 서대문구 연세로7안길 21, 2층 (창천동)
# 0      서울특별시 서대문구 창천동 52-77번지        서울특별시 서대문구 연세로7길 34-6 (창천동)
# 1      서울특별시 서대문구 창천동 52-77번지        서울특별시 서대문구 연세로7길 34-6 (창천동)
# 0      서울특별시 서대문구 창천동 52-44 1층     서울특별시 서대문구 연세로9길 19, 1층 (창천동)
# 0        서울특별시 서대문구 창천동 62-59         서울특별시 서대문구 연세로5다길 14 (창천동)
# 1        서울특별시 서대문구 창천동 62-59         서울특별시 서대문구 연세로5다길 14 (창천동)
# 0       서울특별시 서대문구 창천동 52-8번지         서울특별시 서대문구 연세로11길 10 (창천동)
# 1       서울특별시 서대문구 창천동 52-8번지         서울특별시 서대문구 연세로11길 10 (창천동)
# 2       서울특별시 서대문구 창천동 52-8번지         서울특별시 서대문구 연세로11길 10 (창천동)
# 0         서울특별시 서대문구 창천동 33-43     서울특별시 서대문구 연세로 23, 지상2층 (창천동)
# 1         서울특별시 서대문구 창천동 33-43     서울특별시 서대문구 연세로 23, 지상2층 (창천동)
# 0  서울특별시 서대문구 창천동 5-94 (지하1층)   서울특별시 서대문구 연세로4길 48 (창천동,(지하1층))
# 0   서울특별시 서대문구 창천동 52-79 2층 전체     서울특별시 서대문구 연세로7길 32, 2층 (창천동)
# 1   서울특별시 서대문구 창천동 52-79 2층 전체     서울특별시 서대문구 연세로7길 32, 2층 (창천동)
# 2   서울특별시 서대문구 창천동 52-79 2층 전체     서울특별시 서대문구 연세로7길 32, 2층 (창천동)
# 0      서울특별시 서대문구 창천동 52-75번지         서울특별시 서대문구 연세로7안길 29 (창천동)
# 1      서울특별시 서대문구 창천동 52-75번지         서울특별시 서대문구 연세로7안길 29 (창천동)
# 0   서울특별시 서대문구 창천동 62-66 1층 전체    서울특별시 서대문구 연세로5다길 16, 1층 (창천동)
#
#                업체명          업종  \
# 0         버거킹 연세로점         햄버거
# 1      만족커피 신촌연세대점      카페,디저트
# 2             카페포엠          카페
# 0       오늘통닭 신촌직영점      치킨,닭강정
# 0          한림돈가 본점      돼지고기구이
# 1          몽주방 신촌점        요리주점
# 2              송준옥          한식
# 3             청춘술방        요리주점
# 4     시장을여는사람들 신촌점        요리주점
# 5         인쌩맥주 신촌점       맥주,호프
# 6             오향미엔         중식당
# 7              신촌관        요리주점
# 8             비쿠리야         일식당
# 0           멘지 신촌점       일본식라면
# 0         맘맘테이블 본점       베트남음식
# 1       명성양꼬치 신촌본점         양꼬치
# 0           신촌다성수산         게요리
# 0            마익스케빈        요리주점
# 0        청년샐러드 & 펍    다이어트,샐러드
# 1       썬더치킨 신촌연대점      치킨,닭강정
# 0            밥은먹었어          한식
# 1  기영이 숯불두마리치킨 신촌점      치킨,닭강정
# 2             LP시대        요리주점
# 0           우리이동갈비     육류,고기요리
# 1           카페 프루티       맥주,호프
# 0            쿠마네꼬치        이자카야
# 1            신촌장군집     육류,고기요리
# 2            신촌양꼬치         양꼬치
# 3          크리스탈 후카        요리주점
# 4         테마(크리스탈)        요리주점
# 0           치치 신촌점        요리주점
# 1            다모토리2       맥주,호프
# 0          매거진 스탠딩       맥주,호프
# 1              비틀즈      바(BAR)
# 0             착한곱창          한식
# 0             한울타리      돼지고기구이
# 1               스윙          술집
# 0              데이지  스파게티,파스타전문
# 1           준서네양꼬치         양꼬치
# 2              숯미남      치킨,닭강정
# 0           설빙 신촌점          빙수
# 1          채선당 신촌점        샤브샤브
# 0              와사비         생선회
# 0           하우스라운지      바(BAR)
# 1     세븐레드 홀덤펍 신촌점       맥주,호프
# 2            만남양꼬치         양꼬치
# 0            Day 1      바(BAR)
# 1          D BETTY      카페,디저트
# 0              고기랑     육류,고기요리
#
#                                                  URL          ID
# 0  https://pcmap.place.naver.com/restaurant/33352...    33352177
# 1  https://pcmap.place.naver.com/restaurant/19226...  1922645907
# 2  https://pcmap.place.naver.com/restaurant/13158...    13158412
# 0  https://pcmap.place.naver.com/restaurant/33040...    33040288
# 0  https://pcmap.place.naver.com/restaurant/37688...    37688284
# 1  https://pcmap.place.naver.com/restaurant/19856...  1985698800
# 2  https://pcmap.place.naver.com/restaurant/15227...  1522744322
# 3  https://pcmap.place.naver.com/restaurant/11896...  1189668345
# 4  https://pcmap.place.naver.com/restaurant/16537...  1653766087
# 5  https://pcmap.place.naver.com/restaurant/12273...  1227361695
# 6  https://pcmap.place.naver.com/restaurant/16812...  1681222394
# 7  https://pcmap.place.naver.com/restaurant/10236...  1023651848
# 8  https://pcmap.place.naver.com/restaurant/19555...  1955532479
# 0  https://pcmap.place.naver.com/restaurant/10907...  1090749936
# 0  https://pcmap.place.naver.com/restaurant/17359...  1735994422
# 1  https://pcmap.place.naver.com/restaurant/18699...  1869929725
# 0  https://pcmap.place.naver.com/restaurant/15933...  1593321372
# 0  https://pcmap.place.naver.com/restaurant/11172...  1117240311
# 0  https://pcmap.place.naver.com/restaurant/17460...  1746007185
# 1  https://pcmap.place.naver.com/restaurant/36823...    36823914
# 0  https://pcmap.place.naver.com/restaurant/18726...  1872621752
# 1  https://pcmap.place.naver.com/restaurant/16791...  1679110400
# 2  https://pcmap.place.naver.com/restaurant/31950...    31950029
# 0  https://pcmap.place.naver.com/restaurant/18241...    18241099
# 1  https://pcmap.place.naver.com/restaurant/12906...  1290612242
# 0  https://pcmap.place.naver.com/restaurant/19462...  1946215575
# 1  https://pcmap.place.naver.com/restaurant/10145...  1014541541
# 2  https://pcmap.place.naver.com/restaurant/13411...    13411055
# 3  https://pcmap.place.naver.com/restaurant/16351...  1635145646
# 4  https://pcmap.place.naver.com/restaurant/15640...  1564035425
# 0  https://pcmap.place.naver.com/restaurant/18063...  1806374593
# 1  https://pcmap.place.naver.com/restaurant/13158...    13158409
# 0  https://pcmap.place.naver.com/restaurant/18140...  1814030705
# 1  https://pcmap.place.naver.com/restaurant/37943...    37943813
# 0  https://pcmap.place.naver.com/restaurant/14364...  1436458587
# 0  https://pcmap.place.naver.com/restaurant/31949...    31949398
# 1  https://pcmap.place.naver.com/restaurant/18240...    18240540
# 0  https://pcmap.place.naver.com/restaurant/13640...  1364093770
# 1  https://pcmap.place.naver.com/restaurant/14288...  1428843376
# 2  https://pcmap.place.naver.com/restaurant/17474...  1747496639
# 0  https://pcmap.place.naver.com/restaurant/35150...    35150556
# 1  https://pcmap.place.naver.com/restaurant/18746...    18746815
# 0  https://pcmap.place.naver.com/restaurant/18241...    18241748
# 0  https://pcmap.place.naver.com/restaurant/12636...  1263669347
# 1  https://pcmap.place.naver.com/restaurant/16153...  1615353462
# 2  https://pcmap.place.naver.com/restaurant/10061...  1006154708
# 0  https://pcmap.place.naver.com/restaurant/12535...  1253518962
# 1  https://pcmap.place.naver.com/restaurant/14290...  1429038604
# 0  https://pcmap.place.naver.com/restaurant/15364...  1536458444
