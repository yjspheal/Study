# %%
# 모듈 import
import pandas as pd
from selenium import webdriver
from selenium.webdriver import ActionChains
from selenium.webdriver.support import expected_conditions as EC
from selenium.webdriver.support.ui import WebDriverWait
from webdriver_manager.chrome import ChromeDriverManager
from selenium.webdriver.chrome.service import Service as ChromeService
from selenium.webdriver.common.by import By
from selenium.webdriver.common.keys import Keys
from selenium.common.exceptions import TimeoutException, NoSuchFrameException, NoSuchElementException
from bs4 import BeautifulSoup
import time

# %% [markdown]
# ## 크롤링하고자 하는 음식 카테고리 지정
# - 네이버지도 검색에 '00역 음식점', '00역 맛집' 등 검색 시 등장하는 음식 카테고리 크롤링

# %% [markdown]
# ### 음식 카테고리 크롤링

# %%
# 검색 결과가 표시되는 iframe으로 전환
def search_iframe():
    driver.switch_to.default_content() # 차상위 (기본) 프레임으로 전환
    driver.switch_to.frame("searchIframe") # 검색 결과 프레임으로 전환

def entry_iframe():
    driver.switch_to.default_content() # 차상위 (기본) 프레임으로 전환
    WebDriverWait(driver, 2).until(EC.presence_of_element_located((By.XPATH, '//*[@id="entryIframe"]'))) # WebDriverWait : entryIframe이 나타날 때까지 대기

    # for 문으로 총 5번까지 시도, 0.5초간 대기 후 프레임 전환을 시도 -> frame 전환에 성공하면 break 문으로 빠져나온다
    for i in range(5):
        time.sleep(1.5)
        try:
            driver.switch_to.frame(driver.find_element(By.XPATH, '//*[@id="entryIframe"]'))
            break
        except:
            pass

# 화면에 표시된 업체명을 확인하는 함수
def chk_names():
    search_iframe() # search 프레임으로 전환
    elem = driver.find_elements(By.XPATH, '//*[@id="_pcmap_list_scroll_container"]/ul/li/div[1]/a[1]/div/div/span[1]') # 해당 프레임에서 Xpath를 사용하여 업체명이 표시된 요소를 찾음 원래는 //*[@id="_pcmap_list_scroll_container"]/ul/li/div[1]/div/a[1]/div/div/span[1]
    name_list = [e.text for e in elem] # find_elements 함수로 업체명이 표시된 요소를 모두 찾고, 그 중 text 값을 가져와서 리스트에 저장

    return elem, name_list


def chk_details():
    entry_iframe() # 세부 정보의 iframe으로 전환
    soup = BeautifulSoup(driver.page_source, 'html.parser')
#     print(soup)
    # 데이터 쌓기 - 업종, 주소, url 순
    try:
        category = soup.find('span', {'class': 'lnJFt'})
    except:
        category = float('nan')


    try:
        # 특정 meta 태그를 찾기
        meta_tag = soup.find('meta', {'id': 'og:url'})

        # URL에서 숫자 부분만 추출
        if meta_tag:
            url = meta_tag['content']
            ID = url.split('/')[4]
    except:
        ID = float('nan')

    search_iframe() # 다시 검색 결과의 iframe으로 전환

    return category, url, ID

def crawling_main():
    global naver_res # 전역변수 naver_res 사용 (크롤링 데이터를 저장하는 데이터프레임)
    category_list = [] # 업종 리스트
    url_list = [] # url 리스트
    ID_list = []

    for e in elem:
        try:
            e.click()
            category, url, ID = chk_details() # 업체의 세부 정보 가져오기
        except:
            category = ''
            url=''
            ID =''
        

        # 가져온 정보를 리스트에 추가
        category_list.append(category)
        url_list.append(url)
        ID_list.append(ID)

    naver_temp = pd.DataFrame([name_list, category_list, url_list, ID_list], index = naver_res.columns).T
    naver_res = pd.concat([naver_res, naver_temp])
    naver_res.to_excel('./naver_crawling_result.xlsx')



# webdriver 실행
driver = webdriver.Chrome(service=ChromeService(ChromeDriverManager().install()))
keyword = '신촌역 맛집'
url = f'https://map.naver.com/p/search/{keyword}'
driver.get(url)
# 마우스 및 키보드 동작 시뮬레이터
action = ActionChains(driver)
# 불러올 정보를 담을 빈 데이터프레임 생성
naver_res = pd.DataFrame(columns=['업체명','업종','URL','ID'])

last_name = ''

page_num = 1

while True:
    time.sleep(1.5)
    search_iframe()
    elem, name_list = chk_names()
    if last_name == name_list[-1]:
        break
    while True:
        # 자동 스크롤 구현부
        driver.execute_script("arguments[0].scrollIntoView(true);", elem[-1])
        time.sleep(1.5)
        elem, name_list = chk_names()
        if last_name == name_list[-1]:
            break
        else:
            last_name = name_list[-1]
    crawling_main()
    # 다음 페이지로 이동
    try:
        next_button = driver.find_elements(By.CLASS_NAME, 'eUTV2')[-1]
        next_button.click()
    except:
        break

# %% [markdown]
# ### 검색 시 등장한 음식 카테고리 확인

# %%
set(naver_res['업종'].apply(lambda x: x.text))

# %% [markdown]
# ### 크롤링 대상 음식 카테고리 지정

# %%
target_categories = ['게요리', '곱창,막창,양', '과일,주스전문점', '국밥', '국수', '김밥', '낙지요리', '냉면', 
    '다이어트,샐러드', '닭갈비', '닭발', '도시락,컵밥', '돈가스', '돼지고기구이', '두부요리', 
    '딤섬,중식만두', '떡볶이', '만두', '매운탕,해물탕', '맥주,호프', '바(BAR)', '베이글', '베이커리', 
    '베트남음식', '북카페', '분식', '브런치카페', '샌드위치', '생선회', '샤브샤브', '소고기구이', 
    '스테이크,립', '스파게티,파스타전문', '아시아음식', '양갈비', '양꼬치', '양식', '오뎅,꼬치', 
    '와인', '와플', '요리주점', '우동,소바', '육류,고기요리', '이자카야', '이탈리아음식', '인도음식', 
    '일식당', '일식튀김,꼬치', '장어,먹장어요리', '조개요리', '족발,보쌈', '종합분식', '주꾸미요리', 
    '중식당', '찌개,전골', '초밥,롤', '치킨,닭강정', '카페', '카페,디저트', '칼국수,만두', '케이크전문', 
    '태국음식', '테이크아웃커피', '토스트', '포장마차', '퓨전음식', '프랑스음식', '피자', '한식', 
    '한식뷔페', '한정식-일반', '해물,생선요리', '해장국', '햄버거', '감자탕', '곰탕,설렁탕', '기사식당', 
    '덮밥', '라면', '문래돼지불백', '백반,가정식', '백숙,삼계탕', '복어요리', '빙수', '순대,순댓국', 
    '아이스크림', '오므라이스', '죽', '찜닭', '추어탕', '카레', '패밀리레스토랑', '향토음식', 
    '홍차전문점', '후렌치후라이', '호떡', '쌈밥', '아귀찜,해물찜', '닭볶음탕', '대게요리', '마라탕', 
    '멕시코,남미음식', '브런치', '스페인음식', '정육식당', '전통,민속주점', '일본식라면']

# %% [markdown]
# ## 크롤링하고자 하는 동 지정 (ex_ 아현동)

# %%
# 각자 동에 맞는 거로!
restaurant = pd.read_csv("./서울시마포구일반음식점인허가정보.csv")
restaurant = restaurant[restaurant['영업상태명'] == '영업/정상']

# NaN 값을 빈 문자열로 대체, 안 하면 에러남
restaurant['지번주소'] = restaurant['지번주소'].fillna('')


# '지번주소' 열이 '서울특별시 마포구 --동'으로 시작하는 행만 선택
target_dong = '서울특별시마포구연남동'
#dong = restaurant[restaurant['지번주소'].str.startswith(target_dong)]
dong = restaurant[restaurant['지번주소'].str.replace(' ', '').str.startswith(target_dong)]

# dong에서 도로명주소를 기준으로 검색할 것이기 때문에, 주소 기준 중복인 행을 다 없앰
dong = dong.drop_duplicates(subset='도로명주소', keep=False)
dong.reset_index(drop=True, inplace=True)
len(dong) # 해당 동의 음식점 개수
# Out:
# C:\Users\uje10\AppData\Local\Temp\ipykernel_22920\3753707766.py:2: DtypeWarning: Columns (41,42) have mixed types. Specify dtype option on import or set low_memory=False.
#   restaurant = pd.read_csv("./서울시마포구일반음식점인허가정보.csv")
# 796

# %% [markdown]
# ## 크롤링하고자 하는 동 내 음식점 ID 추출

# %%
# webdriver 실행
#driver = webdriver.Chrome(service=ChromeService(ChromeDriverManager().install()))
driver = webdriver.Chrome()
# 검색 결과가 표시되는 iframe으로 전환
def search_iframe():
    driver.switch_to.default_content()  # 차상위 (기본) 프레임으로 전환
    try:
        time.sleep(1.5)  # 페이지 로딩 대기
        driver.switch_to.frame("searchIframe")  # 검색 결과 프레임으로 전환
    except NoSuchElementException:
        print("searchIframe을 찾을 수 없습니다.")
        return False
    return True

# 개별 업체의 세부 정보가 표시되는 iframe으로 전환
def entry_iframe():
    driver.switch_to.default_content()  # 차상위 (기본) 프레임으로 전환
    try:
        time.sleep(1.5)  # 페이지 로딩 대기
        driver.switch_to.frame("entryIframe")  # 세부 정보 프레임으로 전환
    except NoSuchElementException:
        print("entryIframe을 찾을 수 없습니다.")
        return False
    return True

# type1의 화면에 표시된 업체명을 확인하는 함수
def chk_names_type1():
    search_iframe()  # search 프레임으로 전환
    elems = driver.find_elements(By.CLASS_NAME, 'place_bluelink.C6RjW')
    name_list = []
    category_list = []
    elements = []
    
    for e in elems:
        try:
            name = e.find_element(By.CLASS_NAME, 'YwYLL').text
            category = e.find_element(By.CLASS_NAME, 'YzBgS').text
            
            # 업종이 target_categories에 포함되지 않으면 패스
            if category not in target_categories:
                continue
                
            name_list.append(name)
            category_list.append(category)
            elements.append(e)
        except:
            continue
            
    return elements, name_list, category_list

# type2의 화면에 표시된 업체명을 확인하는 함수
def chk_names_type2(processed_names):
    elems = driver.find_elements(By.CLASS_NAME, 'search_box')
    name_list = []
    category_list = []
    elements = []
    
    for e in elems:
        try:
            name = e.find_element(By.CLASS_NAME, 'search_title').text
            category = e.find_element(By.CLASS_NAME, 'category').text
            
            # 이미 처리된 이름은 패스
            if name in processed_names:
                continue
            
            # 업종이 target_categories에 포함되지 않으면 패스
            if category not in target_categories:
                continue
                
            name_list.append(name)
            category_list.append(category)
            elements.append(e)
        except:
            continue
            
    return elements, name_list, category_list

# 세부 페이지에서 URL과 ID를 추출하는 함수 (type1)
def chk_details():
    if not entry_iframe():  # 세부 정보의 iframe으로 전환
        return float('nan'), float('nan')
    soup = BeautifulSoup(driver.page_source, 'html.parser')
    try:
        # 특정 meta 태그를 찾기
        meta_tag = soup.find('meta', {'id': 'og:url'})

        # URL에서 숫자 부분만 추출
        if meta_tag:
            url = meta_tag['content']
            ID = url.split('/')[4]
    except:
        url = float('nan')
        ID = float('nan')

    search_iframe()  # 다시 검색 결과의 iframe으로 전환
    return url, ID

# 세부 페이지에서 URL과 ID를 추출하는 함수 (type2)
def chk_details_type2():
    if not entry_iframe():  # 세부 정보의 iframe으로 전환
        return float('nan'), float('nan')
    soup = BeautifulSoup(driver.page_source, 'html.parser')
    try:
        # 특정 meta 태그를 찾기
        meta_tag = soup.find('meta', {'id': 'og:url'})

        # URL에서 숫자 부분만 추출
        if meta_tag:
            url = meta_tag['content']
            ID = url.split('/')[4]
    except:
        url = float('nan')
        ID = float('nan')

    return url, ID

# 크롤링 메인 함수
def crawling_main(type):
    global naver_res  # 전역변수 naver_res 사용 (크롤링 데이터를 저장하는 데이터프레임)
    global target_dong
    
    processed_names = set()  # 이미 처리된 업체명을 추적하기 위한 집합
    
    if type == "type1":
        elements, name_list, category_list = chk_names_type1()
        details_func = chk_details
        
        id_list = []
        url_list = []

        for e in elements:
            try:
                e.click()  # 업체명 클릭
                time.sleep(1.5)  # 페이지 로딩 대기
                url, ID = details_func()  # 업체의 세부 정보 가져오기
                url_list.append(url)
                id_list.append(ID)

            except:
                url_list.append(float('nan'))
                id_list.append(float('nan'))
                continue
        
        # 새로운 데이터프레임 생성
        naver_temp = pd.DataFrame({
            '지번주소': [current_jibun] * len(name_list),
            '도로명주소': [current_keyword] * len(name_list),
            '업체명': name_list,
            '업종': category_list,
            'URL': url_list,
            'ID': id_list
        })
        
        # 기존 데이터프레임과 결합
        naver_res = pd.concat([naver_res, naver_temp])
        naver_res.reset_index(drop=True, inplace=True)
        naver_res.to_csv(f'./{target_dong.split()[-1]}.csv')  # 결과를 csv 파일로 저장
        
    if type == "type2":
        all_name_list = []
        all_category_list = []
        all_id_list = []
        all_url_list = []
        
        while True:
            elements, name_list, category_list = chk_names_type2(processed_names)
            details_func = chk_details_type2

            if len(elements) == 0:
                break

            for e, name, category in zip(elements, name_list, category_list):
                try:
                    e.click()  # 업체명 클릭
                    time.sleep(1.5)  # 페이지 로딩 대기
                    url, ID = details_func()  # 업체의 세부 정보 가져오기
                    all_url_list.append(url)
                    all_id_list.append(ID)
                    processed_names.add(name)  # 처리된 이름을 추가
                    all_name_list.append(name)
                    all_category_list.append(category)
                    driver.back()  # 뒤로가기 버튼 클릭
                    time.sleep(1.5)  # 뒤로가기 후 페이지 로딩 대기
                except:
                    continue
        
        # 새로운 데이터프레임 생성
        naver_temp = pd.DataFrame({
            '지번주소': [current_jibun] * len(all_name_list),
            '도로명주소': [current_keyword] * len(all_name_list),
            '업체명': all_name_list,
            '업종': all_category_list,
            'URL': all_url_list,
            'ID': all_id_list
        })

        # 기존 데이터프레임과 결합
        naver_res = pd.concat([naver_res, naver_temp])
        naver_res.to_csv(f'./{target_dong.split()[-1]}.csv')  # 결과를 csv 파일로 저장

# 불러올 정보를 담을 빈 데이터프레임 생성
# naver_res = pd.DataFrame(columns=['지번주소', '도로명주소', '업체명', '업종', 'URL', 'ID'])
naver_res = pd.read_csv('서울특별시마포구서교동.csv')


for index, row in dong[452:].iterrows():
    current_jibun = row['지번주소']  # '지번주소'를 저장
    current_keyword = row['도로명주소']  # '도로명주소'를 검색 키워드로 사용
    
    print(f'전체 {len(dong)} 중 {index+1}, 주소:{current_jibun}')
    
    url = f'https://map.naver.com/p/search/{current_keyword}'
    driver.get(url)

    # "sc-1wsjitl dunggE overlap" 클래스가 있는지 확인
    try:
        time.sleep(1.5)  # 페이지 로딩 대기
        overlap_element = driver.find_element(By.CLASS_NAME, 'sc-1wsjitl.dunggE.overlap')
        try:
            more_button = overlap_element.find_element(By.CLASS_NAME, 'link_more')
            more_button.click()
            time.sleep(1.5)  # "더보기" 버튼 클릭 후 페이지 로딩 대기
        except NoSuchElementException:
            pass  # "더보기" 버튼이 없는 경우 그냥 넘어감
        crawling_main("type2")
    except NoSuchElementException:
        try:
            no_result = driver.find_element(By.CLASS_NAME, 'correction_result_text')
            continue
        except:
            try:
                crawling_main("type1")
            except NoSuchElementException:
                continue

    action = ActionChains(driver)
driver.quit()
# Out:
# 전체 796 중 1, 주소:서울특별시 마포구 연남동 227-1번지 1층
# 전체 796 중 2, 주소:서울특별시 마포구 연남동 228-1
# 전체 796 중 3, 주소:서울특별시 마포구 연남동 568-23 (1층)
# 전체 796 중 4, 주소:서울특별시 마포구 연남동 260-28 1층
# 전체 796 중 5, 주소:서울특별시 마포구 연남동 509-14번지 1층
# 전체 796 중 6, 주소:서울특별시 마포구 연남동 228-5
# 전체 796 중 7, 주소:서울특별시 마포구 연남동 566-8번지 1층
# 전체 796 중 8, 주소:서울특별시 마포구 연남동 224-19
# 전체 796 중 9, 주소:서울특별시 마포구 연남동 487-366번지
# 전체 796 중 10, 주소:서울특별시 마포구 연남동 561-2
# 전체 796 중 11, 주소:서울특별시 마포구 연남동 228-26번지
# 전체 796 중 12, 주소:서울특별시 마포구 연남동 259-5
# 전체 796 중 13, 주소:서울특별시 마포구 연남동 228-40
# 전체 796 중 14, 주소:서울특별시 마포구 연남동 228-42
# 전체 796 중 15, 주소:서울특별시 마포구 연남동 487-412
# 전체 796 중 16, 주소:서울특별시 마포구 연남동 562-27번지 (1층)
# 전체 796 중 17, 주소:서울특별시 마포구 연남동 561-8번지 (1층)
# 전체 796 중 18, 주소:서울특별시 마포구 연남동 562-26
# 전체 796 중 19, 주소:서울특별시 마포구 연남동 258-14
# 전체 796 중 20, 주소:서울특별시 마포구 연남동 493-31번지
# 전체 796 중 21, 주소:서울특별시 마포구 연남동 487-71
# 전체 796 중 22, 주소:서울특별시 마포구 연남동 487-226
# 전체 796 중 23, 주소:서울특별시 마포구 연남동 226-29번지 지하1층
# 전체 796 중 24, 주소:서울특별시 마포구 연남동 361-11번지 1층
# 전체 796 중 25, 주소:서울특별시 마포구 연남동 487-241번지
# 전체 796 중 26, 주소:서울특별시 마포구 연남동 568-25번지 1층
# 전체 796 중 27, 주소:서울특별시 마포구 연남동 487-164번지 1층
# 전체 796 중 28, 주소:서울특별시 마포구 연남동 228-21
# 전체 796 중 29, 주소:서울특별시 마포구 연남동 390-24번지
# 전체 796 중 30, 주소:서울특별시 마포구 연남동 224-33 1층
# 전체 796 중 31, 주소:서울특별시 마포구 연남동 364-25번지
# 전체 796 중 32, 주소:서울특별시 마포구 연남동 487-398
# 전체 796 중 33, 주소:서울특별시 마포구 연남동 369-15번지 1층
# 전체 796 중 34, 주소:서울특별시 마포구 연남동 258-1 2층
# 전체 796 중 35, 주소:서울특별시 마포구 연남동 226-16번지
# 전체 796 중 36, 주소:서울특별시 마포구 연남동 226-29번지 1층
# 전체 796 중 37, 주소:서울특별시 마포구 연남동 224-60
# 전체 796 중 38, 주소:서울특별시 마포구 연남동 487-105번지 1층
# 전체 796 중 39, 주소:서울특별시 마포구 연남동 224-26 대웅빌딩 1층
# 전체 796 중 40, 주소:서울특별시 마포구 연남동 509-20번지 외1필지 1층
# 전체 796 중 41, 주소:서울특별시 마포구 연남동 493-30번지 1층 103호
# 전체 796 중 42, 주소:서울특별시 마포구 연남동 258-5번지 1층
# 전체 796 중 43, 주소:서울특별시 마포구 연남동 382-27 27번지
# 전체 796 중 44, 주소:서울특별시 마포구 연남동 566-67
# 전체 796 중 45, 주소:서울특별시 마포구 연남동 255-21번지 1층 가운데
# 전체 796 중 46, 주소:서울특별시 마포구 연남동 373-15
# 전체 796 중 47, 주소:서울특별시 마포구 연남동 487-135
# 전체 796 중 48, 주소:서울특별시 마포구 연남동 573번지
# 전체 796 중 49, 주소:서울특별시 마포구 연남동 390-28번지
# 전체 796 중 50, 주소:서울특별시 마포구 연남동 566-64
# 전체 796 중 51, 주소:서울특별시 마포구 연남동 227-22 대원빌딩
# 전체 796 중 52, 주소:서울특별시 마포구 연남동 223-15번지
# 전체 796 중 53, 주소:서울특별시 마포구 연남동 504-33번지 1층
# 전체 796 중 54, 주소:서울특별시 마포구 연남동 373-15번지
# 전체 796 중 55, 주소:서울특별시 마포구 연남동 487-378번지 지층 일부
# 전체 796 중 56, 주소:서울특별시 마포구 연남동 228-42번지
# 전체 796 중 57, 주소:서울특별시 마포구 연남동 487-111번지
# 전체 796 중 58, 주소:서울특별시 마포구 연남동 257-20 1층
# 전체 796 중 59, 주소:서울특별시 마포구 연남동 561-6
# 전체 796 중 60, 주소:서울특별시 마포구 연남동 358-1번지
# 전체 796 중 61, 주소:서울특별시 마포구 연남동 254-24번지 지하1층
# 전체 796 중 62, 주소:서울특별시 마포구 연남동 566-6번지
# 전체 796 중 63, 주소:서울특별시 마포구 연남동 570-36
# 전체 796 중 64, 주소:서울특별시 마포구 연남동 257-16번지
# 전체 796 중 65, 주소:서울특별시 마포구 연남동 504-1
# 전체 796 중 66, 주소:서울특별시 마포구 연남동 568-23번지
# 전체 796 중 67, 주소:서울특별시 마포구 연남동 225-33
# 전체 796 중 68, 주소:서울특별시 마포구 연남동 566-64
# 전체 796 중 69, 주소:서울특별시 마포구 연남동 390-59
# 전체 796 중 70, 주소:서울특별시 마포구 연남동 257-23
# 전체 796 중 71, 주소:서울특별시 마포구 연남동 571-3번지
# 전체 796 중 72, 주소:서울특별시 마포구 연남동 257-8
# 전체 796 중 73, 주소:서울특별시 마포구 연남동 255-20번지
# 전체 796 중 74, 주소:서울특별시 마포구 연남동 229-56
# 전체 796 중 75, 주소:서울특별시 마포구 연남동 488-11 101호 일부 101호
# 전체 796 중 76, 주소:서울특별시 마포구 연남동 226-22 101호
# 전체 796 중 77, 주소:서울특별시 마포구 연남동 226-23
# 전체 796 중 78, 주소:서울특별시 마포구 연남동 255-20
# 전체 796 중 79, 주소:서울특별시 마포구 연남동 568-20
# 전체 796 중 80, 주소:서울특별시 마포구 연남동 229-33
# 전체 796 중 81, 주소:서울특별시 마포구 연남동 241-44번지 메종드코튼
# 전체 796 중 82, 주소:서울특별시 마포구 연남동 504-32번지
# 전체 796 중 83, 주소:서울특별시 마포구 연남동 227-1
# 전체 796 중 84, 주소:서울특별시 마포구 연남동 226-29번지 106호
# 전체 796 중 85, 주소:서울특별시 마포구 연남동 257-12번지 1층일부
# 전체 796 중 86, 주소:서울특별시 마포구 연남동 567-56번지 지1층
# 전체 796 중 87, 주소:서울특별시 마포구 연남동 369-20번지
# 전체 796 중 88, 주소:서울특별시 마포구 연남동 229-64 2층
# 전체 796 중 89, 주소:서울특별시 마포구 연남동 562-27번지 1층일부
# 전체 796 중 90, 주소:서울특별시 마포구 연남동 227-13 1층
# 전체 796 중 91, 주소:서울특별시 마포구 연남동 227-13번지 지1층
# 전체 796 중 92, 주소:서울특별시 마포구 연남동 488-4
# 전체 796 중 93, 주소:서울특별시 마포구 연남동 567-39번지 1층
# 전체 796 중 94, 주소:서울특별시 마포구 연남동 228-9 지1층
# 전체 796 중 95, 주소:서울특별시 마포구 연남동 229-67 1층 일부
# 전체 796 중 96, 주소:서울특별시 마포구 연남동 255-25
# 전체 796 중 97, 주소:서울특별시 마포구 연남동 227-15번지
# 전체 796 중 98, 주소:서울특별시 마포구 연남동 487-422번지
# 전체 796 중 99, 주소:서울특별시 마포구 연남동 566-51번지 1층일부(우측)
# 전체 796 중 100, 주소:서울특별시 마포구 연남동 561-3번지 1층일부
# 전체 796 중 101, 주소:서울특별시 마포구 연남동 373-10
# 전체 796 중 102, 주소:서울특별시 마포구 연남동 228-4 1층일부
# 전체 796 중 103, 주소:서울특별시 마포구 연남동 226-29
# 전체 796 중 104, 주소:서울특별시 마포구 연남동 255-21 1층일부
# 전체 796 중 105, 주소:서울특별시 마포구 연남동 385-6번지
# 전체 796 중 106, 주소:서울특별시 마포구 연남동 257-7 1층 101호
# 전체 796 중 107, 주소:서울특별시 마포구 연남동 227-34 1층
# 전체 796 중 108, 주소:서울특별시 마포구 연남동 240-1번지 1층일부
# 전체 796 중 109, 주소:서울특별시 마포구 연남동 228-56번지 1층일부
# 전체 796 중 110, 주소:서울특별시 마포구 연남동 223-24
# 전체 796 중 111, 주소:서울특별시 마포구 연남동 224-26 2층
# 전체 796 중 112, 주소:서울특별시 마포구 연남동 257-6번지 지층101호
# 전체 796 중 113, 주소:서울특별시 마포구 연남동 387-10 1층
# 전체 796 중 114, 주소:서울특별시 마포구 연남동 223-102번지 1층일부
# 전체 796 중 115, 주소:서울특별시 마포구 연남동 387-6
# 전체 796 중 116, 주소:서울특별시 마포구 연남동 229-56 지하1층
# 전체 796 중 117, 주소:서울특별시 마포구 연남동 561-2번지 1층일부
# 전체 796 중 118, 주소:서울특별시 마포구 연남동 383-80
# 전체 796 중 119, 주소:서울특별시 마포구 연남동 260-39 1,2층
# 전체 796 중 120, 주소:서울특별시 마포구 연남동 224-40번지 지하1층
# 전체 796 중 121, 주소:서울특별시 마포구 연남동 229-56 1층
# 전체 796 중 122, 주소:서울특별시 마포구 연남동 387-12 하늘드리움
# 전체 796 중 123, 주소:서울특별시 마포구 연남동 260-49 지하1층
# 전체 796 중 124, 주소:서울특별시 마포구 연남동 509-22번지 지1층일부
# 전체 796 중 125, 주소:서울특별시 마포구 연남동 260-41 지1층
# 전체 796 중 126, 주소:서울특별시 마포구 연남동 223-93번지 지1층
# 전체 796 중 127, 주소:서울특별시 마포구 연남동 260-41번지 지하1층일부좌측
# 전체 796 중 128, 주소:서울특별시 마포구 연남동 255-6번지
# 전체 796 중 129, 주소:서울특별시 마포구 연남동 227-20번지 상암빌딩1층일부
# 전체 796 중 130, 주소:서울특별시 마포구 연남동 566-12 지1층일부
# 전체 796 중 131, 주소:서울특별시 마포구 연남동 223-110 지1층일부
# 전체 796 중 132, 주소:서울특별시 마포구 연남동 241-51번지 1층
# 전체 796 중 133, 주소:서울특별시 마포구 연남동 487-422번지 레이즈빌딩1층일부(103호)
# 전체 796 중 134, 주소:서울특별시 마포구 연남동 482-39번지 지1층,1층일부
# 전체 796 중 135, 주소:서울특별시 마포구 연남동 509-13번지 1층일부
# 전체 796 중 136, 주소:서울특별시 마포구 연남동 390-25 지1층일부
# 전체 796 중 137, 주소:서울특별시 마포구 연남동 260-41번지 1층
# 전체 796 중 138, 주소:서울특별시 마포구 연남동 260-28번지 지1층
# 전체 796 중 139, 주소:서울특별시 마포구 연남동 390-83번지 1층
# 전체 796 중 140, 주소:서울특별시 마포구 연남동 241-18번지
# 전체 796 중 141, 주소:서울특별시 마포구 연남동 390-37번지
# 전체 796 중 142, 주소:서울특별시 마포구 연남동 229-12번지 하하빌딩
# 전체 796 중 143, 주소:서울특별시 마포구 연남동 226-36번지 104호
# 전체 796 중 144, 주소:서울특별시 마포구 연남동 225-8번지 1층101호
# 전체 796 중 145, 주소:서울특별시 마포구 연남동 226-36번지 1층3호
# 전체 796 중 146, 주소:서울특별시 마포구 연남동 226-29번지 1층일부
# 전체 796 중 147, 주소:서울특별시 마포구 연남동 375-116 1층
# 전체 796 중 148, 주소:서울특별시 마포구 연남동 226-21번지
# 전체 796 중 149, 주소:서울특별시 마포구 연남동 228-20 1층
# 전체 796 중 150, 주소:서울특별시 마포구 연남동 384-7번지 1층
# 전체 796 중 151, 주소:서울특별시 마포구 연남동 260-14 1층
# 전체 796 중 152, 주소:서울특별시 마포구 연남동 240-1
# 전체 796 중 153, 주소:서울특별시 마포구 연남동 260-60 거구빌딩 2층
# 전체 796 중 154, 주소:서울특별시 마포구 연남동 566-67 1층일부
# 전체 796 중 155, 주소:서울특별시 마포구 연남동 384-7 2층
# 전체 796 중 156, 주소:서울특별시 마포구 연남동 224-35번지 1층일부(정면우측1칸)
# 전체 796 중 157, 주소:서울특별시 마포구 연남동 258-2번지 2층
# 전체 796 중 158, 주소:서울특별시 마포구 연남동 565-19
# 전체 796 중 159, 주소:서울특별시 마포구 연남동 383-103 1층
# 전체 796 중 160, 주소:서울특별시 마포구 연남동 241-17
# 전체 796 중 161, 주소:서울특별시 마포구 연남동 258-10 지1층
# 전체 796 중 162, 주소:서울특별시 마포구 연남동 383-23번지 1층
# 전체 796 중 163, 주소:서울특별시 마포구 연남동 387-24
# 전체 796 중 164, 주소:서울특별시 마포구 연남동 381-5 지1층일부
# 전체 796 중 165, 주소:서울특별시 마포구 연남동 383-23번지 지1층
# 전체 796 중 166, 주소:서울특별시 마포구 연남동 373-14번지 2층일부
# 전체 796 중 167, 주소:서울특별시 마포구 연남동 566-60번지 1층
# 전체 796 중 168, 주소:서울특별시 마포구 연남동 227-20번지 상암빌딩 2층일부
# 전체 796 중 169, 주소:서울특별시 마포구 연남동 260-47번지
# 전체 796 중 170, 주소:서울특별시 마포구 연남동 515-22 까사벨라 1층101호
# 전체 796 중 171, 주소:서울특별시 마포구 연남동 566-38번지 1층일부
# 전체 796 중 172, 주소:서울특별시 마포구 연남동 390-68번지
# 전체 796 중 173, 주소:서울특별시 마포구 연남동 228-26 1층
# 전체 796 중 174, 주소:서울특별시 마포구 연남동 568-30
# 전체 796 중 175, 주소:서울특별시 마포구 연남동 381-5
# 전체 796 중 176, 주소:서울특별시 마포구 연남동 260-25번지 1층전부
# 전체 796 중 177, 주소:서울특별시 마포구 연남동 227-5
# 전체 796 중 178, 주소:서울특별시 마포구 연남동 260-25번지
# 전체 796 중 179, 주소:서울특별시 마포구 연남동 566-61
# 전체 796 중 180, 주소:서울특별시 마포구 연남동 478-15번지 풀하우스연남
# 전체 796 중 181, 주소:서울특별시 마포구 연남동 224-6 지층일부
# 전체 796 중 182, 주소:서울특별시 마포구 연남동 241-26번지
# 전체 796 중 183, 주소:서울특별시 마포구 연남동 228-59
# 전체 796 중 184, 주소:서울특별시 마포구 연남동 566-56
# 전체 796 중 185, 주소:서울특별시 마포구 연남동 241-81번지 1층
# 전체 796 중 186, 주소:서울특별시 마포구 연남동 565-31번지
# 전체 796 중 187, 주소:서울특별시 마포구 연남동 383-82
# 전체 796 중 188, 주소:서울특별시 마포구 연남동 383-44
# 전체 796 중 189, 주소:서울특별시 마포구 연남동 570-38
# 전체 796 중 190, 주소:서울특별시 마포구 연남동 383-103
# 전체 796 중 191, 주소:서울특별시 마포구 연남동 383-99
# 전체 796 중 192, 주소:서울특별시 마포구 연남동 241-26번지
# 전체 796 중 193, 주소:서울특별시 마포구 연남동 260-51번지
# 전체 796 중 194, 주소:서울특별시 마포구 연남동 383-44
# 전체 796 중 195, 주소:서울특별시 마포구 연남동 241-18번지 1층일부
# 전체 796 중 196, 주소:서울특별시 마포구 연남동 240-23 1층
# 전체 796 중 197, 주소:서울특별시 마포구 연남동 493-5번지 1층일부
# 전체 796 중 198, 주소:서울특별시 마포구 연남동 515-20번지
# 전체 796 중 199, 주소:서울특별시 마포구 연남동 260-52 2,3층
# 전체 796 중 200, 주소:서울특별시 마포구 연남동 260-52번지 지하1층
# 전체 796 중 201, 주소:서울특별시 마포구 연남동 566-55
# 전체 796 중 202, 주소:서울특별시 마포구 연남동 383-99
# 전체 796 중 203, 주소:서울특별시 마포구 연남동 228-2번지 2층우측
# 전체 796 중 204, 주소:서울특별시 마포구 연남동 228-47번지
# 전체 796 중 205, 주소:서울특별시 마포구 연남동 390-73번지 1층
# 전체 796 중 206, 주소:서울특별시 마포구 연남동 390-51
# 전체 796 중 207, 주소:서울특별시 마포구 연남동 260-51 2층
# 전체 796 중 208, 주소:서울특별시 마포구 연남동 260-31번지
# 전체 796 중 209, 주소:서울특별시 마포구 연남동 570-28번지
# 전체 796 중 210, 주소:서울특별시 마포구 연남동 260-45 지1층
# 전체 796 중 211, 주소:서울특별시 마포구 연남동 228-44 1층일부
# 전체 796 중 212, 주소:서울특별시 마포구 연남동 229-34
# 전체 796 중 213, 주소:서울특별시 마포구 연남동 260-52
# 전체 796 중 214, 주소:서울특별시 마포구 연남동 361-10번지
# 전체 796 중 215, 주소:서울특별시 마포구 연남동 384-11
# 전체 796 중 216, 주소:서울특별시 마포구 연남동 361-10번지 3층
# 전체 796 중 217, 주소:서울특별시 마포구 연남동 383-95
# 전체 796 중 218, 주소:서울특별시 마포구 연남동 241-98
# 전체 796 중 219, 주소:서울특별시 마포구 연남동 385-6
# 전체 796 중 220, 주소:서울특별시 마포구 연남동 387-7번지
# 전체 796 중 221, 주소:서울특별시 마포구 연남동 390-78번지
# 전체 796 중 222, 주소:서울특별시 마포구 연남동 390-42번지
# 전체 796 중 223, 주소:서울특별시 마포구 연남동 382-19번지 지하1층
# 전체 796 중 224, 주소:서울특별시 마포구 연남동 382-19번지
# 전체 796 중 225, 주소:서울특별시 마포구 연남동 387-13
# 전체 796 중 226, 주소:서울특별시 마포구 연남동 227-23 챕터 연남
# 전체 796 중 227, 주소:서울특별시 마포구 연남동 228-25 지층
# 전체 796 중 228, 주소:서울특별시 마포구 연남동 383-95
# 전체 796 중 229, 주소:서울특별시 마포구 연남동 390-28번지
# 전체 796 중 230, 주소:서울특별시 마포구 연남동 454-13 1~4층
# 전체 796 중 231, 주소:서울특별시 마포구 연남동 390-25번지 지층일부
# 전체 796 중 232, 주소:서울특별시 마포구 연남동 228-34 미소빌딩
# 전체 796 중 233, 주소:서울특별시 마포구 연남동 228-32
# 전체 796 중 234, 주소:서울특별시 마포구 연남동 373-10번지
# 전체 796 중 235, 주소:서울특별시 마포구 연남동 390-37 1층좌측
# 전체 796 중 236, 주소:서울특별시 마포구 연남동 223-8 YJ빌딩
# 전체 796 중 237, 주소:서울특별시 마포구 연남동 260-45
# 전체 796 중 238, 주소:서울특별시 마포구 연남동 566-19번지 1층
# 전체 796 중 239, 주소:서울특별시 마포구 연남동 387-3
# 전체 796 중 240, 주소:서울특별시 마포구 연남동 383-44번지
# 전체 796 중 241, 주소:서울특별시 마포구 연남동 390-71
# 전체 796 중 242, 주소:서울특별시 마포구 연남동 454-12
# 전체 796 중 243, 주소:서울특별시 마포구 연남동 381-15
# 전체 796 중 244, 주소:서울특별시 마포구 연남동 453-32번지
# 전체 796 중 245, 주소:서울특별시 마포구 연남동 390-30
# 전체 796 중 246, 주소:서울특별시 마포구 연남동 390-71번지
# 전체 796 중 247, 주소:서울특별시 마포구 연남동 227-31 지층
# 전체 796 중 248, 주소:서울특별시 마포구 연남동 493-12번지
# 전체 796 중 249, 주소:서울특별시 마포구 연남동 387-19 B02호
# 전체 796 중 250, 주소:서울특별시 마포구 연남동 375-108
# 전체 796 중 251, 주소:서울특별시 마포구 연남동 487-394 HC빌딩
# 전체 796 중 252, 주소:서울특별시 마포구 연남동 390-71
# 전체 796 중 253, 주소:서울특별시 마포구 연남동 387-6
# 전체 796 중 254, 주소:서울특별시 마포구 연남동 241-74
# 전체 796 중 255, 주소:서울특별시 마포구 연남동 223-114번지
# 전체 796 중 256, 주소:서울특별시 마포구 연남동 390-48번지
# 전체 796 중 257, 주소:서울특별시 마포구 연남동 229-55번지
# 전체 796 중 258, 주소:서울특별시 마포구 연남동 373-13
# 전체 796 중 259, 주소:서울특별시 마포구 연남동 240-44
# 전체 796 중 260, 주소:서울특별시 마포구 연남동 228-48번지
# 전체 796 중 261, 주소:서울특별시 마포구 연남동 228-48번지
# 전체 796 중 262, 주소:서울특별시 마포구 연남동 375-113번지
# 전체 796 중 263, 주소:서울특별시 마포구 연남동 387-31
# 전체 796 중 264, 주소:서울특별시 마포구 연남동 226-16
# 전체 796 중 265, 주소:서울특별시 마포구 연남동 390-67
# 전체 796 중 266, 주소:서울특별시 마포구 연남동 387-18번지
# 전체 796 중 267, 주소:서울특별시 마포구 연남동 387-18번지
# 전체 796 중 268, 주소:서울특별시 마포구 연남동 383-38번지
# 전체 796 중 269, 주소:서울특별시 마포구 연남동 383-102
# 전체 796 중 270, 주소:서울특별시 마포구 연남동 390-98
# 전체 796 중 271, 주소:서울특별시 마포구 연남동 227-5 1층일부
# 전체 796 중 272, 주소:서울특별시 마포구 연남동 373-6
# 전체 796 중 273, 주소:서울특별시 마포구 연남동 369-14번지
# 전체 796 중 274, 주소:서울특별시 마포구 연남동 245-63
# 전체 796 중 275, 주소:서울특별시 마포구 연남동 223-14번지
# 전체 796 중 276, 주소:서울특별시 마포구 연남동 228-32
# 전체 796 중 277, 주소:서울특별시 마포구 연남동 228-39
# 전체 796 중 278, 주소:서울특별시 마포구 연남동 223-111 동보빌딩
# 전체 796 중 279, 주소:서울특별시 마포구 연남동 245-49
# 전체 796 중 280, 주소:서울특별시 마포구 연남동 561-3번지 1층
# 전체 796 중 281, 주소:서울특별시 마포구 연남동 570-23번지 102호
# 전체 796 중 282, 주소:서울특별시 마포구 연남동 387-3 지층일부
# 전체 796 중 283, 주소:서울특별시 마포구 연남동 487-343
# 전체 796 중 284, 주소:서울특별시 마포구 연남동 240-22
# 전체 796 중 285, 주소:서울특별시 마포구 연남동 229-59 1층
# 전체 796 중 286, 주소:서울특별시 마포구 연남동 227-2번지 2층
# 전체 796 중 287, 주소:서울특별시 마포구 연남동 373-13번지
# 전체 796 중 288, 주소:서울특별시 마포구 연남동 260-5
# 전체 796 중 289, 주소:서울특별시 마포구 연남동 390-57
# 전체 796 중 290, 주소:서울특별시 마포구 연남동 570-23번지 1층 104호
# 전체 796 중 291, 주소:서울특별시 마포구 연남동 390-94번지 3,4층
# 전체 796 중 292, 주소:서울특별시 마포구 연남동 454-11번지
# 전체 796 중 293, 주소:서울특별시 마포구 연남동 241-80 B101호
# 전체 796 중 294, 주소:서울특별시 마포구 연남동 255-23번지 2층
# 전체 796 중 295, 주소:서울특별시 마포구 연남동 228-10
# 전체 796 중 296, 주소:서울특별시 마포구 연남동 228-25
# 전체 796 중 297, 주소:서울특별시 마포구 연남동 390-24번지 지층일부
# 전체 796 중 298, 주소:서울특별시 마포구 연남동 567-42번지
# 전체 796 중 299, 주소:서울특별시 마포구 연남동 240-29번지
# 전체 796 중 300, 주소:서울특별시 마포구 연남동 387-38
# 전체 796 중 301, 주소:서울특별시 마포구 연남동 390-35 지빌딩
# 전체 796 중 302, 주소:서울특별시 마포구 연남동 567-34번지
# 전체 796 중 303, 주소:서울특별시 마포구 연남동 390-39
# 전체 796 중 304, 주소:서울특별시 마포구 연남동 387-8
# 전체 796 중 305, 주소:서울특별시 마포구 연남동 373-13번지
# 전체 796 중 306, 주소:서울특별시 마포구 연남동 562-5번지
# 전체 796 중 307, 주소:서울특별시 마포구 연남동 387-38
# 전체 796 중 308, 주소:서울특별시 마포구 연남동 375-117번지
# 전체 796 중 309, 주소:서울특별시 마포구 연남동 240-2번지 K&L
# 전체 796 중 310, 주소:서울특별시 마포구 연남동 228-2번지
# 전체 796 중 311, 주소:서울특별시 마포구 연남동 384-10번지
# 전체 796 중 312, 주소:서울특별시 마포구 연남동 370-30
# 전체 796 중 313, 주소:서울특별시 마포구 연남동 240-3 White House
# 전체 796 중 314, 주소:서울특별시 마포구 연남동 240-2 K&L
# 전체 796 중 315, 주소:서울특별시 마포구 연남동 245-44번지
# 전체 796 중 316, 주소:서울특별시 마포구 연남동 258-5번지
# 전체 796 중 317, 주소:서울특별시 마포구 연남동 387-6
# 전체 796 중 318, 주소:서울특별시 마포구 연남동 258-2
# 전체 796 중 319, 주소:서울특별시 마포구 연남동 568-51번지
# 전체 796 중 320, 주소:서울특별시 마포구 연남동 241-75번지
# 전체 796 중 321, 주소:서울특별시 마포구 연남동 568-26번지
# 전체 796 중 322, 주소:서울특별시 마포구 연남동 383-91번지
# 전체 796 중 323, 주소:서울특별시 마포구 연남동 228-2
# 전체 796 중 324, 주소:서울특별시 마포구 연남동 390-64
# 전체 796 중 325, 주소:서울특별시 마포구 연남동 227-24번지
# 전체 796 중 326, 주소:서울특별시 마포구 연남동 387-38 엠케이
# 전체 796 중 327, 주소:서울특별시 마포구 연남동 223-115 Alef House
# 전체 796 중 328, 주소:서울특별시 마포구 연남동 225-12
# 전체 796 중 329, 주소:서울특별시 마포구 연남동 241-18번지
# 전체 796 중 330, 주소:서울특별시 마포구 연남동 383-91
# 전체 796 중 331, 주소:서울특별시 마포구 연남동 259-16
# 전체 796 중 332, 주소:서울특별시 마포구 연남동 390-39
# 전체 796 중 333, 주소:서울특별시 마포구 연남동 487-424번지
# 전체 796 중 334, 주소:서울특별시 마포구 연남동 567-42번지
# 전체 796 중 335, 주소:서울특별시 마포구 연남동 487-93번지
# 전체 796 중 336, 주소:서울특별시 마포구 연남동 387-15번지
# 전체 796 중 337, 주소:서울특별시 마포구 연남동 260-16
# 전체 796 중 338, 주소:서울특별시 마포구 연남동 564-37
# 전체 796 중 339, 주소:서울특별시 마포구 연남동 566-67
# 전체 796 중 340, 주소:서울특별시 마포구 연남동 258-1
# 전체 796 중 341, 주소:서울특별시 마포구 연남동 260-16번지
# 전체 796 중 342, 주소:서울특별시 마포구 연남동 487-21번지
# 전체 796 중 343, 주소:서울특별시 마포구 연남동 568-23
# 전체 796 중 344, 주소:서울특별시 마포구 연남동 570-38번지
# 전체 796 중 345, 주소:서울특별시 마포구 연남동 390-32
# 전체 796 중 346, 주소:서울특별시 마포구 연남동 385-4번지
# 전체 796 중 347, 주소:서울특별시 마포구 연남동 390-3번지
# 전체 796 중 348, 주소:서울특별시 마포구 연남동 382-2
# 전체 796 중 349, 주소:서울특별시 마포구 연남동 382-1
# 전체 796 중 350, 주소:서울특별시 마포구 연남동 504-50 프로젝트 에이
# 전체 796 중 351, 주소:서울특별시 마포구 연남동 487-291
# 전체 796 중 352, 주소:서울특별시 마포구 연남동 382-27번지
# 전체 796 중 353, 주소:서울특별시 마포구 연남동 258-10번지
# 전체 796 중 354, 주소:서울특별시 마포구 연남동 387-24번지
# 전체 796 중 355, 주소:서울특별시 마포구 연남동 241-26번지
# 전체 796 중 356, 주소:서울특별시 마포구 연남동 454-15번지
# 전체 796 중 357, 주소:서울특별시 마포구 연남동 387-39
# 전체 796 중 358, 주소:서울특별시 마포구 연남동 573 코오롱하늘채아파트
# 전체 796 중 359, 주소:서울특별시 마포구 연남동 228-28
# 전체 796 중 360, 주소:서울특별시 마포구 연남동 224-12번지 서빈빌딩
# 전체 796 중 361, 주소:서울특별시 마포구 연남동 387-15
# 전체 796 중 362, 주소:서울특별시 마포구 연남동 241-52번지
# 전체 796 중 363, 주소:서울특별시 마포구 연남동 224-23
# 전체 796 중 364, 주소:서울특별시 마포구 연남동 228-47
# 전체 796 중 365, 주소:서울특별시 마포구 연남동 387-45
# 전체 796 중 366, 주소:서울특별시 마포구 연남동 228-3번지
# 전체 796 중 367, 주소:서울특별시 마포구 연남동 227-24
# 전체 796 중 368, 주소:서울특별시 마포구 연남동 373-10번지
# 전체 796 중 369, 주소:서울특별시 마포구 연남동 381-3번지
# 전체 796 중 370, 주소:서울특별시 마포구 연남동 373-18번지
# 전체 796 중 371, 주소:서울특별시 마포구 연남동 260-16
# 전체 796 중 372, 주소:서울특별시 마포구 연남동 228-8
# 전체 796 중 373, 주소:서울특별시 마포구 연남동 515-19
# 전체 796 중 374, 주소:서울특별시 마포구 연남동 387-19
# 전체 796 중 375, 주소:서울특별시 마포구 연남동 224-18
# 전체 796 중 376, 주소:서울특별시 마포구 연남동 568-21 제이드빌(Jade)
# 전체 796 중 377, 주소:서울특별시 마포구 연남동 228-3
# 전체 796 중 378, 주소:서울특별시 마포구 연남동 383-72
# 전체 796 중 379, 주소:서울특별시 마포구 연남동 383-91
# 전체 796 중 380, 주소:서울특별시 마포구 연남동 241-80
# 전체 796 중 381, 주소:서울특별시 마포구 연남동 228-7
# 전체 796 중 382, 주소:서울특별시 마포구 연남동 241-17
# 전체 796 중 383, 주소:서울특별시 마포구 연남동 387-18
# 전체 796 중 384, 주소:서울특별시 마포구 연남동 260-47
# 전체 796 중 385, 주소:서울특별시 마포구 연남동 383-93 연남빌딩
# 전체 796 중 386, 주소:서울특별시 마포구 연남동 387-45
# 전체 796 중 387, 주소:서울특별시 마포구 연남동 241-31
# 전체 796 중 388, 주소:서울특별시 마포구 연남동 240-53
# 전체 796 중 389, 주소:서울특별시 마포구 연남동 228-59
# 전체 796 중 390, 주소:서울특별시 마포구 연남동 390-35 지빌딩
# 전체 796 중 391, 주소:서울특별시 마포구 연남동 229-51
# 전체 796 중 392, 주소:서울특별시 마포구 연남동 564-37
# 전체 796 중 393, 주소:서울특별시 마포구 연남동 225-13
# 전체 796 중 394, 주소:서울특별시 마포구 연남동 515-19
# 전체 796 중 395, 주소:서울특별시 마포구 연남동 487-24
# 전체 796 중 396, 주소:서울특별시 마포구 연남동 223-14
# 전체 796 중 397, 주소:서울특별시 마포구 연남동 260-47
# 전체 796 중 398, 주소:서울특별시 마포구 연남동 487-23
# 전체 796 중 399, 주소:서울특별시 마포구 연남동 259-16
# 전체 796 중 400, 주소:서울특별시 마포구 연남동 453-9
# 전체 796 중 401, 주소:서울특별시 마포구 연남동 228-42
# 전체 796 중 402, 주소:서울특별시 마포구 연남동 229-67
# 전체 796 중 403, 주소:서울특별시 마포구 연남동 454-7
# 전체 796 중 404, 주소:서울특별시 마포구 연남동 390-100
# 전체 796 중 405, 주소:서울특별시 마포구 연남동 390-71
# 전체 796 중 406, 주소:서울특별시 마포구 연남동 241-86
# 전체 796 중 407, 주소:서울특별시 마포구 연남동 387-26
# 전체 796 중 408, 주소:서울특별시 마포구 연남동 228-55
# 전체 796 중 409, 주소:서울특별시 마포구 연남동 387-31
# 전체 796 중 410, 주소:서울특별시 마포구 연남동 566-60
# 전체 796 중 411, 주소:서울특별시 마포구 연남동 383-95
# 전체 796 중 412, 주소:서울특별시 마포구 연남동 228-21
# 전체 796 중 413, 주소:서울특별시 마포구 연남동 260-46
# 전체 796 중 414, 주소:서울특별시 마포구 연남동 383-78
# 전체 796 중 415, 주소:서울특별시 마포구 연남동 228-8
# 전체 796 중 416, 주소:서울특별시 마포구 연남동 224-18
# 전체 796 중 417, 주소:서울특별시 마포구 연남동 240-38
# 전체 796 중 418, 주소:서울특별시 마포구 연남동 384-7
# 전체 796 중 419, 주소:서울특별시 마포구 연남동 223-111 동보빌딩
# 전체 796 중 420, 주소:서울특별시 마포구 연남동 227-22 대원빌딩
# 전체 796 중 421, 주소:서울특별시 마포구 연남동 228-2
# 전체 796 중 422, 주소:서울특별시 마포구 연남동 384-8
# 전체 796 중 423, 주소:서울특별시 마포구 연남동 387-8
# 전체 796 중 424, 주소:서울특별시 마포구 연남동 383-82 신박사빌딩
# 전체 796 중 425, 주소:서울특별시 마포구 연남동 390-35 지빌딩
# 전체 796 중 426, 주소:서울특별시 마포구 연남동 227-2
# 전체 796 중 427, 주소:서울특별시 마포구 연남동 561-59 세인빌딩
# 전체 796 중 428, 주소:서울특별시 마포구 연남동 258-10
# 전체 796 중 429, 주소:서울특별시 마포구 연남동 570-1
# 전체 796 중 430, 주소:서울특별시 마포구 연남동 244-8
# 전체 796 중 431, 주소:서울특별시 마포구 연남동 566-1
# 전체 796 중 432, 주소:서울특별시 마포구 연남동 373-7
# 전체 796 중 433, 주소:서울특별시 마포구 연남동 223-14
# 전체 796 중 662, 주소:서울특별시 마포구 연남동 390-77
# 전체 796 중 663, 주소:서울특별시 마포구 연남동 562-44 자슬린하우스
# 전체 796 중 664, 주소:서울특별시 마포구 연남동 385-4
# 전체 796 중 665, 주소:서울특별시 마포구 연남동 390-70 신영빌딩
# 전체 796 중 666, 주소:서울특별시 마포구 연남동 564-20 신원빌딩
# 전체 796 중 667, 주소:서울특별시 마포구 연남동 390-35 지빌딩
# 전체 796 중 668, 주소:서울특별시 마포구 연남동 487-269
# 전체 796 중 669, 주소:서울특별시 마포구 연남동 390-26
# 전체 796 중 670, 주소:서울특별시 마포구 연남동 383-24
# 전체 796 중 671, 주소:서울특별시 마포구 연남동 250-3
# 전체 796 중 672, 주소:서울특별시 마포구 연남동 260-31
# 전체 796 중 673, 주소:서울특별시 마포구 연남동 390-72
# 전체 796 중 674, 주소:서울특별시 마포구 연남동 227-23 챕터 연남
# 전체 796 중 675, 주소:서울특별시 마포구 연남동 565-14
# 전체 796 중 676, 주소:서울특별시 마포구 연남동 227-19
# 전체 796 중 677, 주소:서울특별시 마포구 연남동 227-28
# 전체 796 중 678, 주소:서울특별시 마포구 연남동 387-8
# 전체 796 중 679, 주소:서울특별시 마포구 연남동 570-27
# 전체 796 중 680, 주소:서울특별시 마포구 연남동 225-15
# 전체 796 중 681, 주소:서울특별시 마포구 연남동 390-26
# 전체 796 중 682, 주소:서울특별시 마포구 연남동 387-7
# 전체 796 중 683, 주소:서울특별시 마포구 연남동 240-64 일오일 빌딩
# 전체 796 중 684, 주소:서울특별시 마포구 연남동 260-12
# 전체 796 중 685, 주소:서울특별시 마포구 연남동 487-424
# 전체 796 중 686, 주소:서울특별시 마포구 연남동 228-58
# 전체 796 중 687, 주소:서울특별시 마포구 연남동 228-1
# 전체 796 중 688, 주소:서울특별시 마포구 연남동 228-39
# 전체 796 중 689, 주소:서울특별시 마포구 연남동 240-41
# 전체 796 중 690, 주소:서울특별시 마포구 연남동 387-25 보고스
# 전체 796 중 691, 주소:서울특별시 마포구 연남동 223-24
# 전체 796 중 692, 주소:서울특별시 마포구 연남동 568-19
# 전체 796 중 693, 주소:서울특별시 마포구 연남동 227-5
# 전체 796 중 694, 주소:서울특별시 마포구 연남동 375-111
# 전체 796 중 695, 주소:서울특별시 마포구 연남동 487-378
# 전체 796 중 696, 주소:서울특별시 마포구 연남동 565-14
# 전체 796 중 697, 주소:서울특별시 마포구 연남동 241-87
# 전체 796 중 698, 주소:서울특별시 마포구 연남동 375-111
# 전체 796 중 699, 주소:서울특별시 마포구 연남동 223-90
# 전체 796 중 700, 주소:서울특별시 마포구 연남동 245-83
# 전체 796 중 701, 주소:서울특별시 마포구 연남동 387-45
# 전체 796 중 702, 주소:서울특별시 마포구 연남동 224-23
# 전체 796 중 703, 주소:서울특별시 마포구 연남동 227-22 대원빌딩
# 전체 796 중 704, 주소:서울특별시 마포구 연남동 260-45
# 전체 796 중 705, 주소:서울특별시 마포구 연남동 487-250
# 전체 796 중 706, 주소:서울특별시 마포구 연남동 366-27 다르다타워
# 전체 796 중 754, 주소:서울특별시 마포구 연남동 385-3
# 전체 796 중 755, 주소:서울특별시 마포구 연남동 241-88
# 전체 796 중 756, 주소:서울특별시 마포구 연남동 240-11
# 전체 796 중 757, 주소:서울특별시 마포구 연남동 487-262
# 전체 796 중 758, 주소:서울특별시 마포구 연남동 241-47
# 전체 796 중 759, 주소:서울특별시 마포구 연남동 223-79
# 전체 796 중 760, 주소:서울특별시 마포구 연남동 228-10
# 전체 796 중 761, 주소:서울특별시 마포구 연남동 255-19
# 전체 796 중 762, 주소:서울특별시 마포구 연남동 381-15
# 전체 796 중 763, 주소:서울특별시 마포구 연남동 240-16
# 전체 796 중 764, 주소:서울특별시 마포구 연남동 223-111 동보빌딩
# 전체 796 중 765, 주소:서울특별시 마포구 연남동 383-34
# 전체 796 중 766, 주소:서울특별시 마포구 연남동 240-4
# 전체 796 중 767, 주소:서울특별시 마포구 연남동 240-4
# 전체 796 중 768, 주소:서울특별시 마포구 연남동 228-57
# 전체 796 중 769, 주소:서울특별시 마포구 연남동 390-65
# 전체 796 중 770, 주소:서울특별시 마포구 연남동 361-8
# 전체 796 중 771, 주소:서울특별시 마포구 연남동 487-389
# 전체 796 중 772, 주소:서울특별시 마포구 연남동 224-55
# 전체 796 중 773, 주소:서울특별시 마포구 연남동 390-41
# 전체 796 중 774, 주소:서울특별시 마포구 연남동 245-43
# 전체 796 중 775, 주소:서울특별시 마포구 연남동 383-35
# 전체 796 중 776, 주소:서울특별시 마포구 연남동 260-27
# 전체 796 중 777, 주소:서울특별시 마포구 연남동 260-2
# 전체 796 중 778, 주소:서울특별시 마포구 연남동 241-41 Plan M
# 전체 796 중 779, 주소:서울특별시 마포구 연남동 487-34
# 전체 796 중 780, 주소:서울특별시 마포구 연남동 223-17
# 전체 796 중 781, 주소:서울특별시 마포구 연남동 387-24
# 전체 796 중 782, 주소:서울특별시 마포구 연남동 227-16
# 전체 796 중 783, 주소:서울특별시 마포구 연남동 390-78
# 전체 796 중 784, 주소:서울특별시 마포구 연남동 369-20
# 전체 796 중 785, 주소:서울특별시 마포구 연남동 224-11
# 전체 796 중 786, 주소:서울특별시 마포구 연남동 241-74
# 전체 796 중 787, 주소:서울특별시 마포구 연남동 260-38
# 전체 796 중 788, 주소:서울특별시 마포구 연남동 229-10
# 전체 796 중 789, 주소:서울특별시 마포구 연남동 260-38
# 전체 796 중 790, 주소:서울특별시 마포구 연남동 228-56
# 전체 796 중 791, 주소:서울특별시 마포구 연남동 487-24
# 전체 796 중 792, 주소:서울특별시 마포구 연남동 227-28
# 전체 796 중 793, 주소:서울특별시 마포구 연남동 240-16
# 전체 796 중 794, 주소:서울특별시 마포구 연남동 245-70
# 전체 796 중 795, 주소:서울특별시 마포구 연남동 224-51
# 전체 796 중 796, 주소:서울특별시 마포구 연남동 390-65

# %% [markdown]
# ## 중복행 제거 및 저장

# %%
# 중복행 제거
naver_res_drop = naver_res.drop_duplicates(subset='ID', keep='first')

# %%
# CSV 파일로 저장
naver_res_drop.to_csv('서교동.csv', index=False, encoding = 'utf-8-sig')
