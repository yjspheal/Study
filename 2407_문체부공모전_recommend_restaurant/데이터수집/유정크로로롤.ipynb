# %% [markdown]
# <h1>Table of Contents<span class="tocSkip"></span></h1>
# <div class="toc"><ul class="toc-item"></ul></div>

# %%
add_list = ['서울특별시 서대문구 거북골로 19-1 (홍은동)',
'서울특별시 서대문구 통일로11길 3 (천연동)',
'서울특별시 서대문구 수색로 28-5 (남가좌동)',
'서울특별시 서대문구 수색로4길 13 (남가좌동)',
'서울특별시 서대문구 명물길 63, 지상1층 (창천동)',
'서울특별시 서대문구 통일로 111 (미근동)',
'서울특별시 서대문구 이화여대2가길 24 (대현동)',
'서울특별시 서대문구 충정로 73, 1층 (충정로2가)',
'서울특별시 서대문구 통일로9안길 36-2, 1층 (충정로2가)',
'서울특별시 서대문구 수색로2길 19-3 (남가좌동)']

# %%
# 모듈 가져오기

from selenium import webdriver
from webdriver_manager.chrome import ChromeDriverManager
from selenium.webdriver.chrome.service import Service as ChromeService
from selenium.webdriver.common.by import By
from selenium.webdriver.common.keys import Keys

from bs4 import BeautifulSoup
import time

# %%
# Chrome WebDriver를 초기화합니다.
driver = webdriver.Chrome(service=ChromeService(ChromeDriverManager().install()))

# 요청할 URL
base_url = 'https://map.naver.com/p/search/'

places = []

# %%
for add in add_list[:3]:
    url = f'{base_url}{add}?c=15.00,0,0,0,dh'
    driver.get(url)
    
    # 페이지 로드 후 5초 대기
    time.sleep(5)
    
    # 페이지 소스 가져오기
    page_source = driver.page_source
    soup = BeautifulSoup(page_source, 'html.parser')
    
    print(soup)
    # 스크립트 태그에서 특정 내용 추출
    script_tag = soup.find('script', text=lambda x: x and 'window.__APOLLO_STATE__' in x)
    
    print(script_tag)
    if script_tag:
        script_content = script_tag.string
        # window.__APOLLO_STATE__ 데이터 추출
        start_index = script_content.find('window.__APOLLO_STATE__ = ') + len('window.__APOLLO_STATE__ = ')
        end_index = script_content.find(';', start_index)
        json_data = script_content[start_index:end_index].strip()
        data = json.loads(json_data)
        
        print(data)
        
        # PlaceSummary 항목들 추출
        for key, value in data.items():
            if key.startswith("PlaceSummary:"):
                place_id = value.get('id')
                place_name = value.get('name')
                place_category = value.get('category')
                places.append((place_id, place_name, place_category))

# 결과 출력
for place in places:
    print(f"ID: {place[0]}, Name: {place[1]}, Category: {place[2]}")
# Out:
# <html lang="ko"><head><meta charset="utf-8"/><meta content="width=device-width,initial-scale=1" name="viewport"/><meta content="website" property="og:type"/><meta content="always" name="referrer"/><title>서울특별시 서대문구 거북골로 19-1 (홍은동) 검색 - 네이버 지도</title><meta content="공간을 검색합니다. 생활을 연결합니다. 장소, 버스, 지하철, 도로 등 모든 공간의 정보를 하나의 검색으로 연결한 새로운 지도를 만나보세요." data-rh="true" name="Description"/><meta content="공간을 검색합니다. 생활을 연결합니다. 장소, 버스, 지하철, 도로 등 모든 공간의 정보를 하나의 검색으로 연결한 새로운 지도를 만나보세요." data-rh="true" property="og:description"/><meta content="공간을 검색합니다. 생활을 연결합니다. 장소, 버스, 지하철, 도로 등 모든 공간의 정보를 하나의 검색으로 연결한 새로운 지도를 만나보세요." data-rh="true" property="twitter:description"/><meta content="https://search.pstatic.net/common/?src=https%3A%2F%2Fssl.pstatic.net%2Fstatic%2Fmaps%2Fv5%2Fpc%2Fnaver-map.png&amp;type=f&amp;size=1200x630&amp;quality=80&amp;opt=2" data-rh="true" property="og:image"/><meta content="https://search.pstatic.net/common/?src=https%3A%2F%2Fssl.pstatic.net%2Fstatic%2Fmaps%2Fv5%2Fpc%2Fnaver-map.
# ...

# %%
from bs4 import BeautifulSoup
from selenium.webdriver.common.action_chains import ActionChains
from selenium.webdriver.common.keys import Keys




driver = webdriver.Chrome(service=ChromeService(ChromeDriverManager().install()))


# URL로 이동
url = 'https://pcmap.place.naver.com/restaurant/1241416220/'
driver.get(url+'home')

# 페이지가 모두 로드될 때까지 잠시 대기
time.sleep(5)  # 필요에 따라 대기 시간을 조정할 수 있습니다.

# # 끝까지 스크롤 다운
# last_height = driver.execute_script("return document.body.scrollHeight")

# while True:
#     # 스크롤 다운
#     driver.execute_script("window.scrollTo(0, document.body.scrollHeight);")
    
#     # 페이지 로드 대기
#     time.sleep(2)  # 페이지 로딩 대기 시간 조정 가능

#     # 새로운 높이 계산
#     new_height = driver.execute_script("return document.body.scrollHeight")
    
#     # 더 이상 스크롤할 내용이 없으면 종료
#     if new_height == last_height:
#         break
#     last_height = new_height


# 페이지 소스 가져오기
page_source = driver.page_source

# BeautifulSoup 객체 생성
soup = BeautifulSoup(page_source, 'html.parser')

# 식당 이름
restaurant_name = soup.find('span', class_='GHAhO').text.strip()
print(f"Restaurant Name: {restaurant_name}")

# 카테고리 및 상태
category = soup.find('span', class_='lnJFt').text.strip()
status = soup.find('span', class_='PI7f0').text.strip()
print(f"Category: {category}, Status: {status}")

# 주소
address = soup.find('div', class_='O8qbU tQY7D').find('span', class_='LDgIH').text.strip()
print(f"Address: {address}")

# 전화번호
phone_number = soup.find('div', class_='O8qbU nbXkr').find('span', class_='xlx7Q').text.strip()
print(f"Phone Number: {phone_number}")

# 홈페이지 링크
website_links = soup.find('div', class_='O8qbU yIPfO').find_all('a', class_='place_bluelink')
websites = [link['href'] for link in website_links]
print(f"Websites: {websites}")

# 영업시간
business_hours = soup.find('div', class_='O8qbU pSavy').find('div', class_='A_cdD').text.strip()
print(f"Business Hours: {business_hours}")


driver.get(url+'menu/list')

# 페이지가 모두 로드될 때까지 잠시 대기
time.sleep(5)  # 필요에 따라 대기 시간을 조정할 수 있습니다.

# 페이지 소스 가져오기
page_source = driver.page_source

# BeautifulSoup 객체 생성
soup = BeautifulSoup(page_source, 'html.parser')

# 메뉴 항목 추출, 수정 필요. 끝까지 안 나옴. 버튼 클릭
menu_items = []
menu_section = soup.find('div', class_='place_section_content').find_all('li', class_='E2jtL')
for item in menu_section:
    menu_name = item.find('span', class_='lPzHi').text.strip()
    menu_price = item.find('div', class_='GXS1X').find('em').text.strip() + '원'
    menu_items.append({'name': menu_name, 'price': menu_price})

print("Menu Items:")
for menu_item in menu_items:
    print(f"  - {menu_item['name']}: {menu_item['price']}")

# 메뉴판 이미지 링크 추출
menu_image_section = soup.find_all('div', class_='place_section_content')[-1]
if menu_image_section:
    menu_image_link = menu_image_section.find('img', class_='_img')['src']
    print(f"Menu Image Link: {menu_image_link}")

# 방문자 리뷰
reviews = []
review_section = soup.find('div', class_='place_section_content').find_all('li', class_='j1aq2')
for review in review_section:
    review_text = review.find('span', class_='zPfVt').text.strip()
    reviewer_name = review.find('div', class_='EjEHm').text.strip()
    review_date = review.find('time').text.strip()
    visit_count = review.find('span', class_='s4fVo', text=lambda x: '번째 방문' in x).text.strip()
    keywords = [kw.text.strip() for kw in review.find_all('span', class_='sIv5s')]
    reviews.append({
        'reviewer': reviewer_name,
        'date': review_date,
        'visit_count': visit_count,
        'keywords': keywords,
        'text': review_text
    })
print("Visitor Reviews:")
for review in reviews:
    print(f"  - Reviewer: {review['reviewer']}")
    print(f"  - Date: {review['date']}")
    print(f"  - Visit Count: {review['visit_count']}")
    print(f"  - Keywords: {', '.join(review['keywords'])}")
    print(f"  - Text: {review['text']}")

    
driver.get(url+'review/visitor')

# 페이지가 모두 로드될 때까지 잠시 대기
time.sleep(5)  # 필요에 따라 대기 시간을 조정할 수 있습니다.

# 페이지 소스 가져오기
page_source = driver.page_source
soup = BeautifulSoup(page_source, 'html.parser')

# '더보기' 버튼 요소 찾기
buttons = soup.find_all('a', class_='sIv5s WPk67', attrs={'aria-expanded': 'false'})
# print(buttons)

# 각 버튼 클릭하기
for index, button in enumerate(buttons):
    # '더보기' 버튼의 고유 속성으로 Selenium에서 해당 요소를 찾기
    try:
        selenium_button = driver.find_elements(By.XPATH, "//a[@class='sIv5s WPk67' and @aria-expanded='false']")[index]

        # 요소 스크롤하여 보기로 만들기
        driver.execute_script("arguments[0].scrollIntoView();", selenium_button)

        # 요소 클릭
        selenium_button.click()

        # 클릭 후 잠시 대기
        time.sleep(1)
    except Exception as e:
        pass

#         print(f"Error clicking button {index}: {e}")


# 페이지 소스 가져오기
page_source = driver.page_source

# BeautifulSoup 객체 생성
soup = BeautifulSoup(page_source, 'html.parser')

# 리뷰 섹션 추출
review_sections = soup.find_all('li', class_='owAeM')

reviews = []

for review in review_sections:
    review_data = {}

    # 리뷰 텍스트 추출
    review_text = review.find('span', class_='zPfVt')
    review_data['text'] = review_text.text.strip() if review_text else 'N/A'


    # 선택한 키워드 추출
    keywords = review.find_all('span', class_='sIv5s')
    review_data['keywords'] = [kw.text.strip() for kw in keywords]

    # 방문일과 방문 횟수 추출
    visit_info = review.find('div', class_='D40bm')
    visit_date = visit_info.find('time').text.strip() if visit_info.find('time') else 'N/A'
    visit_count = visit_info.find_all('span', class_='CKUdu')[1].text.strip() if len(visit_info.find_all('span', class_='CKUdu')) > 1 else 'N/A'

    review_data['visit_date'] = visit_date
    review_data['visit_count'] = visit_count

    reviews.append(review_data)

# 결과 출력
print("Reviews with Texts, Images, Keywords, Visit Dates, and Visit Counts:")
for review in reviews:
    print(f"Text: {review['text']}")
    print(f"Keywords: {', '.join(review['keywords'])}")
    print(f"Visit Date: {review['visit_date']}")
    print(f"Visit Count: {review['visit_count']}")
    print("-" * 40)
# Out:
# Restaurant Name: 일품양평해장국 서대문점
# Category: 해장국, Status: 새로오픈
# Address: 서울 서대문구 통일로11길 3 1층 1호
# Phone Number: 0507-1442-1449
# Websites: ['https://www.instagram.com/_ilpumfood_official/', 'https://blog.naver.com/ghyo0706', 'https://www.ilpumfood.co.kr/index.php']
# Business Hours: 영업 중21:30에 영업 종료21시 30분에 영업 종료
# Menu Items:
#   - 양평해장국: 10,000원
#   - 얼큰양평해장국: 11,000원
#   - 얼큰순대국: 10,000원
#   - 뼈다귀해장국: 10,000원
#   - 내장탕: 13,000원
#   - 우거지해장국: 10,000원
#   - 육개장: 10,000원
#   - 선지해장국: 7,000원
#   - 북어콩나물해장국: 7,000원
#   - 갈비탕: 15,000원
#   - 내장전골: 35,000원
#   - 뼈다귀전골: 35,000원
#   - 돼지내장볶음: 15,000원
#   - 편육: 9,000원
#   - 맛보기편육: 5,000원
# Menu Image Link: https://search.pstatic.net/common/?autoRotate=true&quality=95&type=f320_320&src=https%3A%2F%2Fldb-phinf.pstatic.net%2F20240319_75%2F17108347798828BTBV_JPEG%2FKakaoTalk_20240319_155837554_15.jpg
# Visitor Reviews:
# Reviews with Texts, Images, Keywords, Visit Dates, and Visit Counts:
# Text: 해장국 양도 많고 맛있어요
# 이모님들도 친절하세요
# Keywords: 음식이 맛있어요
# ...
