# %%
# %run ver5.py
# Out:
# rank 3 YT_data 폴더가 이미 존재합니다. 해당 폴더에 데이터를 저장합니다.
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# ~\OneDrive - 서강대학교\바탕 화면\서강\7학기\빅데이터컴퓨팅_장나은교수님\과제\웹크롤링 팀플\ver5빅데이터크롤링_5조\ver5.py in <module>
#     302 if __name__=='__main__':
#     303     try :
# --> 304         youtube_crawling()
#     305         excel_add_youtube()
#     306         make_top20
#
# ~\OneDrive - 서강대학교\바탕 화면\서강\7학기\빅데이터컴퓨팅_장나은교수님\과제\웹크롤링 팀플\ver5빅데이터크롤링_5조\ver5.py in youtube_crawling()
#     146         goods = goods_name[i].value   # _name[i] 자체는 셀이기 때문에 value로 셀의 내용을 추출하여 저장
#     147         brand = brand_name[i].value
# --> 148         get_youtube_data(brand, goods)
#     149
#     150
#
# ~\OneDrive - 서강대학교\바탕 화면\서강\7학기\빅데이터컴퓨팅_장나은교수님\과제\웹크롤링 팀플\ver5빅데이터크롤링_5조\ver5.py in get_youtube_data(brand, goods)
#      41     # 전체 데이터를 추출하기 위하여 페에지를 쭉 내림. 필터링이 되기 때문에 50번이면 충분
# ...
