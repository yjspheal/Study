# %%
pip install jupyter jupysql
# Out:
# ...
#    ---------------------------------------- 0.0/95.1 kB ? eta -:--:--
#    -------------------------------------- - 92.2/95.1 kB 2.6 MB/s eta 0:00:01
#    ---------------------------------------- 95.1/95.1 kB 1.3 MB/s eta 0:00:00
# ...
#    ---------------------------------------- 0.0/192.8 kB ? eta -:--:--
#    ------------------- -------------------- 92.2/192.8 kB ? eta -:--:--
#    ----------------------------- ---------- 143.4/192.8 kB 1.7 MB/s eta 0:00:01
#    ---------------------------------------- 192.8/192.8 kB 1.5 MB/s eta 0:00:00
# ...
#    ---------------------------------------- 0.0/464.0 kB ? eta -:--:--
#    --------------- ------------------------ 184.3/464.0 kB 5.6 MB/s eta 0:00:01
#    ------------------------------------- -- 430.1/464.0 kB 6.8 MB/s eta 0:00:01
#    ---------------------------------------- 464.0/464.0 kB 4.2 MB/s eta 0:00:00
# ...
#    ---------------------------------------- 0.0/44.4 kB ? eta -:--:--
# ...

# %%
pip install jupyter jupysql
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.
